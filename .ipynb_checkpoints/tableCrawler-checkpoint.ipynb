# %%
import google # https://pypi.org/project/google/#files
from googlesearch import search 
import pandas as pd
import tabula
import regex as re
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup, SoupStrainer
import httplib2
import validators
import urllib.parse
import time
import warnings
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import sys
import copy

warnings.filterwarnings(action='ignore')

sys.setrecursionlimit(1000)
# More on the google module here:
#https://python-googlesearch.readthedocs.io/en/latest/index.html#module-googlesearch

# An alternative here maybe:
# https://github.com/Nv7-GitHub/googlesearch/blob/master/googlesearch/__init__.py

# %%
# Get links hosting each LAs account statments.
def getLinks(names):
    
    # Empty list for saving links.
    links = []
    
    # Initialize search number (for pausing after a number of searches)
    searchNum = 0
    
    for council in names:
        print(council)
        
        # Increment search number by 1
        searchNum += 1
        print(searchNum)
        
        # Search terms (on query/council)
        query = r'{} statement of accounts'.format(council)
        
        # Google search using 'query' above and save as object.
        queryObj = search(query, tld = 'com', stop = 10)
        
        # Quick and dirty way of getting something from a generator object.
        for j in queryObj:
            if not j.endswith('pdf'):
                links.append(j)
                break
        
        # Add a pause to the search every 30th term to avoid 'Too Many Requests'
        if searchNum%30 == 0:
            time.sleep(1000)
        
        
    return links

# %%
# query = r'{} statement of accounts "gov.uk"'.format('bedford')

# # Google search using 'query' above and save as object.
# queryObj = search(query, tld = 'com', stop = 10)

# # Quick and dirty way of getting something from a generator object.
# for j in queryObj:
#     if not j.endswith('pdf'):
#         print(j)

# %%
# # Get list of all councils
# councilNames = pd.read_csv('./councilNames.csv', sep = ",")
# councilNames = councilNames['x'].str.lower()

# # Get link to page where account statements will
# # be for each council.
# councilLinks = getLinks(councilNames)

# # Save as df -> csv 
# dfLinks = pd.DataFrame(data = {"Councils": councilNames, "Link": councilLinks})
# dfLinks.to_csv("./councilLinks.csv", sep = ',', index = False)

# Load csv
councilLinks_df = pd.read_csv('./councilLinks.csv')
# councilLinks = councilLinks_df['Link'] 
councilLinks_df.set_index('Councils', inplace = True)

print(councilLinks_df.shape[0])
print(len(councilNames))

# They have the same length, but we don't know 
# if we actually got one link per LA 
# e.g. some searches might've returned news articles or
# other stuff.

# It's not straighforward to check, so will go ahead
# with the assumption that we got all relevant links
# and see if there's any anomalies when getting the 
# PDFs from the pages.
# Out:
# 370
# 370

# %%
# Changing some of the links manually (based on results below)
councilLinks_df.loc['woking']['Link'] = 'http://datashare.woking.gov.uk/View/financial-documents/statement-of-accounts'
councilLinks_df.loc['basingstoke & deane']['Link'] = 'https://www.basingstoke.gov.uk/finance'
councilLinks_df.loc['bassetlaw']['Link'] = 'https://data.bassetlaw.gov.uk/statement-of-accounts/'
councilLinks_df.loc['cumbria']['Link'] = 'https://cumbria.gov.uk/finance/finance/statementofaccounts.asp#'
councilLinks_df.loc['hartlepool ua']['Link'] = 'https://www.hartlepool.gov.uk/downloads/download/299/statement_of_accounts'
councilLinks_df.loc['central bedfordshire ua']['Link'] = 'https://www.centralbedfordshire.gov.uk/info/27/about_your_council/178/annual_accounts_fees_and_charges_budget_statements_and_budget_books'
councilLinks_df.loc['central bedfordshire ua']['Link'] = 'https://info.westberks.gov.uk/article/30394'
councilLinks_df.loc['redcar & cleveland ua']['Link'] = 'https://www.redcar-cleveland.gov.uk/about-the-council/budgets/statement-of-accounts/Pages/summary-statement-of-accounts.aspx'
councilLinks_df.loc['bolsover']['Link'] ='https://www.bolsover.gov.uk/a/196-accounts-and-budgets/244-accounts'

# %%
def addLink(pdfs, councilLink, pdfLink):
    
    
    # Join 'base' link of council with link for statement.
    fullLink = urllib.parse.urljoin(councilLink, pdfLink['href'])
    
    # Add link to pdfs dict.
    # 'Description': 'link'
    pdfs[pdfLink.text] = fullLink
    
    return pdfs
    

def makeSearchTerms(yearL, yearH, other = []):
    
    # Different combinations of years
    # Would be nice to get a nice regex here.
    substrings_v1 = [yearL, yearH]
    substrings_v2 = [yearL, yearH[2:]]
    substrings_v3 = [yearL[2:], yearH[2:]]
    substrings_v4 = [yearL + yearH]
    substrings_v5 = [yearL + yearH[2:]]
    
    allSubstrings = [substrings_v1, substrings_v2, substrings_v3, substrings_v4, substrings_v5]
    
    if other != []:
        for ss in allSubstrings:
            ss.extend(other)
    
    return allSubstrings
    


def accessLink(councilLink):
    try:
        response = requests.get(councilLink, 
                                timeout = 15,
                               headers = {'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True))
        return soup
    except requests.exceptions.RequestException as e:
        return 0


def conditions(subStrVers, link):
    '''
    Checks if all elements of a list (of strings) are present in a link.
    subStrVers is a list of lists, so that different versions of the lists can be checked.
    Makes more sense after looking at findStatements() below.
    
    Input: 
        subStrVers - a list of lists.
        link - a string. 
    
    Outputs True if conditions are satisfied, False otherwise.
    '''
    satisfied = False
    
    # Search in file name/descriptions.
    for ss in subStrVers:
        if all(s in link.text.lower() for s in ss):
            satisfied = True
            break
            
    
    # Search in link name.
    for ss in subStrVers:
        if all(s in link['href'].lower() for s in ss):
            satisfied = True
            break
    

    return satisfied        

    
    

# List all pdfs from a url.
def findStatements(councilLink, yearL, yearH, otherTerms = [], pdfs = {}):  
      
    soup = accessLink(councilLink)
    
    # If site can't be accessed stop and return empty pdfs.
    if soup == 0:
        return pdfs

    
    allSubstrings = makeSearchTerms(yearL, yearH, other = otherTerms)
    
    # Find all files containing 'pdf'
    for link in soup.select("a[href*='pdf']"):
        
        if conditions(allSubstrings, link):
            addLink(pdfs, councilLink, link)
        

    # If none found above, look at all links and see if terms
    # can be found in the link or description
    if pdfs == {}:
        for link in soup.select("a"):
            if conditions(allSubstrings, link):
                
                # Add link to 'pdfs' dict. 
                addLink(pdfs, councilLink, link)
                

            
    # Some councils have statements for different years
    # on different webpages. If this is the case, figure out
    # the relevant page, and call findStatements recurseively. 
    if pdfs == {}:
        # This is really messy as I was basically trying 
        # to add conditions as I went, could probably use some cleaning up.
        
        # Initial candidate for new council link (i.e. selection)
        selection = soup.select("a[href*='{}-{}']".format(yearL,yearH))
        
        # If a link containing 'yearL'-'yearH' not available.
        if len(selection) == 0:
            # Try 'yearL' - 'yearH'[2:], e.g. '2017' - '18'
            selection = soup.select("a[href*='{}-{}']".format(yearL,yearH[2:]))
            
        # If 'yearL' - 'yearH'[2:] not available, try 'yearL'[2:] - 'yearH'[2:]
        if len(selection) == 0:
            selection = soup.select("a[href*='{}-{}']".format(yearL[2:],yearH[2:]))
                    
        # If still haven't found anything, try the above w/ different format.
        # e.g. '20172018' (instead of '2017'-'2018')
        if len(selection) == 0:
            selection = soup.select("a[href*='{}{}']".format(yearL,yearH))  
            
        if len(selection) == 0:
            selection = soup.select("a[href*='{}{}']".format(yearL,yearH[2:]))  
            
        if len(selection) == 0:
            selection = soup.select("a[href*='{}{}']".format(yearL[2:],yearH[2:]))     
            
        # If none are available look for 'historical' in link name.       
        if len(selection) == 0:
            selection = soup.select("a[href*='historical']")                  

        # W/ the final selection, clean up the link and call finalStatements again
        # with the new link.
        for link in selection:
#             print("New council link (relavant year)", link['href'])

            newLink = urllib.parse.urljoin(councilLink, link['href'])
            print("Old link:", councilLink)
            print("New line:", newLink)
    
            if newLink == councilLink:
                break
            else:    
                findStatements(newLink, yearL, yearH, otherTerms, pdfs)

    # Some of the accounts aren't actually pdf files
    # So looking at the description of the file as opposed to
    # the actual file extention for the term 'pdf'. 
    if pdfs == {}:
        for link in soup.find_all('a', string = re.compile("pdf", re.IGNORECASE)):
            
            # Add link to 'pdfs' dict.
            addLink(pdfs, councilLink, link)
            break
    
    # If all else fails, just get all the pdfs
    if pdfs == {}:
        for link in soup.select("a[href*='.pdf']"):
            
            # Add link to pdfs dict.    
            addLink(pdfs, councilLink, link)

    # If that also fails get all asp.        
    if pdfs == {}:
        for link in soup.select("a[href*='asp']"):

            # Add link to pdfs dict.    
            addLink(pdfs, councilLink, link)
        
            
    return pdfs 


def getStatements(yearL, yearH):

    allStatements = {el:{} for el in councilLinks_df.index.values.tolist()}
    noPDFs = []
    for el in allStatements:

        allStatements[el] = findStatements(councilLink = councilLinks_df.loc[el]['Link'], \
                                           yearL = yearL, \
                                           yearH = yearH, \
#                                            otherTerms = ['accounts'],\
                                           pdfs = {})
        
#         allStatements[el] = checkStatements(allStatements[el])
        print("Got council: {} ({} links found)".format(el, len(allStatements[el])))

        if len(allStatements[el]) == 0:
            noPDFs.append(el)
            
            
    return allStatements, noPDFs        


def conditionsDict(subStrVers, key):
    
    satisfied = False
    
    for ss in subStrVers:
        if all(s in key for s in ss):
            satisfied = True
            
    return satisfied   



def checkStatement(pdfs, yearL, yearH, otherTerms = []):
    
                   
    testTerms = makeSearchTerms(yearL, yearH, other = otherTerms)
    

    res = [term for key, 
           term in pdfs.items() 
           if (conditionsDict(testTerms, key) or
          conditionsDict(testTerms, term))]
    
    if res != []:
        return res[0]

    
    return res
  

def checkAllStatements(allStatements, yearL, yearH, otherTerms = []):

    for council in allStatements:
        
        allStatements[council] = checkStatement(allStatements[council],
                                               yearL, yearH,
                                               otherTerms = otherTerms)
            
    return allStatements        


def countLinks(allStatements):
    
    count_zero = 0
    count_more = 0

    for el in allStatements:
        if len(allStatements[el]) == 0:
#             print("Zero:", el)
            count_zero +=1

        if len(allStatements[el]) > 1:
#             print("More than 1: ", el)
            count_more +=1

    print("\tLAs with 0 links:", count_zero)
#     print("\tLAs with more than 1 link:", count_more)

# %%
# # 2017 - 2018
# Got council: ealing (0 links found)
# Got council: enfield (1 links found)
# Got council: haringey (2 links found)
# Got council: harrow (3 links found)
# Got council: havering (1 links found)
# Got council: hillingdon (3 links found)
# Got council: hounslow (1 links found)
# Got council: kingston upon thames (0 links found)
# Got council: merton (4 links found)
# Got council: newham (1 links found)
# Got council: redbridge (6 links found)
# Got council: richmond upon thames (4 links found)
# Got council: sutton (2 links found)
# Got council: waltham forest (5 links found)
# Got council: greater london authority (8 links found)
# Got council: east london waste authority (2 links found)
# Got council: merseyside waste disposal authority (1 links found)
# Got council: north london waste authority (2 links found)
# Got council: western riverside waste authority (4 links found)
# Got council: west london waste authority (3 links found)
# Got council: west midlands combined authority (4 links found)
# Got council: greater manchester combined authority (1 links found)
# Got council: liverpool city region combined authority (6 links found)
# Got council: sheffield city region combined authority (0 links found)
# Got council: the west yorkshire combined authority (4 links found)
# Got council: west of england combined authority (4 links found)
# Got council: tees valley combined authority (3 links found)
# Got council: cambridgeshire and peterborough combined authority (1 links found)
# Got council: north east combined authority (3 links found)
# Got council: north of tyne combined authority (1 links found)
# Got council: dartmoor national park authority (3 links found)
# Got council: exmoor national park authority (6 links found)
# Got council: lake district national park authority (6 links found)
# Got council: north york moors national park authority (4 links found)
# Got council: northumberland national park authority (3 links found)
# Got council: peak district national park authority (4 links found)
# Got council: yorkshire dales national park authority (6 links found)
# Got council: the broads authority (12 links found)
# Got council: new forest national park authority (2 links found)
# Got council: south downs national park authority (1 links found)
# Got council: lee valley regional park authority (0 links found)
# {'bath & north east somerset ua': 'https://www.bathnes.gov.uk/services/your-council-and-democracy/budgets-and-spending/annual-accounts/accounts-2018-2019',
#  'bristol ua': [],
#  'south gloucestershire ua': 'https://www.southglos.gov.uk//documents/Audited-Annual-Financial-Report-201819.pdf',
#  'north somerset ua': 'https://www.n-somerset.gov.uk/sites/default/files/2020-02/statement%20of%20accounts%202018-19.pdf',
#  'luton ua': 'https://www.luton.gov.uk/Council_government_and_democracy/Lists/LutonDocuments/PDF/Corporate%20Finance/Accounts/Revised-statement-of-accounts-2018-19.pdf',
#  'bedford ua': 'http://bbcdevwebfiles.blob.core.windows.net/webfiles/Council%20and%20Democracy/Statement%20of%20Accounts/2018-19%20Audited%20Statement%20of%20Accounts%20Bedford%20Borough%20Council%20-%20Final.pdf',
#  'central bedfordshire ua': 'https://info.westberks.gov.uk/CHttpHandler.ashx?id=48703&p=0',
#  'bracknell forest ua': 'https://www.bracknell-forest.gov.uk/sites/default/files/documents/financial-statements-2018-to-2019.pdf',
#  'west berkshire ua': [],
#  'reading ua': 'https://images.reading.gov.uk/2020/02/Statement-of-Accounts-2018-19.pdf',
#  'slough ua': 'https://www.slough.gov.uk/downloads/download/259/2018-2019-published-statement-of-accounts',
#  'windsor & maidenhead ua': 'https://www.rbwm.gov.uk/sites/default/files/2020-04/finance_notice_of_publication_1819.pdf',
#  'wokingham ua': 'https://www.wokingham.gov.uk/council-and-meetings/open-data/datasets-and-open-data/?assetdet91f252ff-550d-4cfa-a838-92ef2cb5f83c=512402&categoryesctl91f252ff-550d-4cfa-a838-92ef2cb5f83c=7778',
#  'milton keynes ua': 'https://www.milton-keynes.gov.uk/assets/attach/66665/Annual-Audit-Letter-18-19.pdf',
#  'buckinghamshire': 'https://www.buckscc.gov.uk/media/4515646/statement-of-accounts-2018-19.pdf',
#  'aylesbury vale': 'https://www.aylesburyvaledc.gov.uk/sites/default/files/page_downloads/Statement%20of%20Accounts%202018-19%20Published.pdf',
#  'chiltern': 'https://www.chiltern.gov.uk/media/15895/19-20-Notice-of-Conclusion-of-Audit/pdf/Conclusion_notice_Chiltern_District_Council.pdf?m=637424377035500000',
#  'south bucks': 'https://www.southbucks.gov.uk/media/14014/Statement-of-Accounts-2018-19/pdf/Audited_accounts_SBDC_1819_v.2.pdf?m=637291044248830000',
#  'wycombe': 'https://www.wycombe.gov.uk/uploads/public/documents/About-the-council/Council-budget-and-spending/Wycombe-DC-Statement-of-accounts-2018-2019.pdf',
#  'peterborough ua': 'https://www.peterborough.gov.uk/asset-library/imported-assets/MediumTermFinancialStrategy201819PhaseOne.pdf',
#  'cambridgeshire': 'https://www.cambridgeshire.gov.uk/asset-library/imported-assets/Change%20of%20Auditor%202018-19.pdf',
#  'cambridge': [],
#  'east cambridgeshire': 'https://www.eastcambs.gov.uk/sites/default/files/East%20Cambs%20Accounts%202018-19%20FINAL%20Version%20with%20audit%20opinion%20-%20Audit%20Certificate.pdf',
#  'fenland': [],
#  'south cambridgeshire': 'https://www.scambs.gov.uk/media/16570/scdc-annual-governance-statement-1718-10-february-2019.pdf',
#  'huntingdonshire': 'https://www.cambridgeshire.gov.uk/asset-library/imported-assets/Change%20of%20Auditor%202018-19.pdf',
#  'halton ua': 'https://www3.halton.gov.uk/Pages/councildemocracy/pdfs/Finance/statementofaccounts/Accounts2018-19/publicnotice.pdf',
#  'warrington ua': 'https://www.warrington.gov.uk/financial-accounts-2018-19',
#  'cheshire east ua': 'https://www.cheshireeast.gov.uk/pdf/council-and-democracy/council-finance-and-governance/final-ags-2018-19-web.pdf',
#  'cheshire west and chester ua': 'https://www.cheshirewestandchester.gov.uk/your-council/how-we-work/budgets-and-finance/documents/notice-of-conclusion-of-audit-2018-19.pdf',
#  'hartlepool ua': 'https://www.hartlepool.gov.uk/downloads/file/5313/financial_report_2018-19',
#  'middlesbrough ua': 'https://www.middlesbrough.gov.uk/sites/default/files/statement_of_accounts_2018-19.pdf',
#  'redcar & cleveland ua': 'https://www.redcar-cleveland.gov.uk/about-the-council/budgets/statement-of-accounts/Documents/Summary%20Accounts%202018-19.pdf',
#  'stockton-on-tees ua': 'https://www.stockton.gov.uk/media/1961883/annual-governance-statement-final-signed.pdf',
#  'cornwall ua': 'https://www.cornwall.gov.uk/media/40599169/cornwall-council-statement-of-accounts-2018-19-post-audit-v4-final-with-audit-opinion.pdf',
#  'cumbria': 'https://cumbria.gov.uk/finance/finance/accounts_2018-19.asp',
#  'allerdale': 'https://www-cloudfront.allerdale.gov.uk/media/filer_public/29/c8/29c82a06-4d21-4b34-8312-7afb9f392c98/audited_statement_of_accounts_2018-19_-_for_publication.pdf',
#  'barrow-in-furness': 'https://www.barrowbc.gov.uk/_resources/assets/attachment/full/0/8017.pdf',
#  'carlisle': [],
#  'copeland': 'https://www.copeland.gov.uk/sites/default/files/attachments/soa_18_19_final.pdf',
#  'eden': 'https://www.eden.gov.uk/media/5548/audited-statement-of-accounts-2018-2019-final.pdf',
#  'south lakeland': 'https://www.southlakeland.gov.uk/media/5063/approved-budget-book-2018-9.pdf',
#  'derby city ua': 'https://www.derby.gov.uk/media/derbycitycouncil/contentassets/documents/reports/financialreports/Draft_Statement_of_Accounts_2018_19.pdf',
#  'derbyshire': 'https://www.derbyshire.gov.uk/site-elements/documents/pdf/council/council-tax/statement-of-accounts/post-audit-statement-of-accounts-2018-to-2019.pdf',
#  'amber valley': [],
#  'bolsover': 'https://www.bolsover.gov.uk/component/edocman/12173-statement-of-accounts-2018-19/download',
#  'chesterfield': 'https://www.chesterfield.gov.uk/media/993478/annual-audit-letter-2018-19.pdf',
#  'derbyshire dales': 'https://www.derbyshiredales.gov.uk/images/documents/S/Statement_of_Accounts_2018-19_Final_310719.pdf',
#  'erewash': [],
#  'high peak': [],
#  'north east derbyshire': [],
#  'south derbyshire': [],
#  'plymouth ua': 'https://www.plymouth.gov.uk/sites/default/files/Statement_of_Accounts_2018_19.pdf',
#  'torbay ua': 'https://www.torbay.gov.uk/media/13410/soa-1819.docx',
#  'devon': 'https://www.devon.gov.uk/finance-and-budget/audit-and-inspection/notice-appointment-auditor-2018-19/',
#  'east devon': [],
#  'exeter': 'https://exeter.gov.uk/media/5040/statement-of-accounts-2018-19-signed-and-with-auditors-report.pdf',
#  'mid devon': 'https://www.middevon.gov.uk/media/347892/annual-accounts-2018-19.pdf',
#  'north devon': 'https://www.northdevon.gov.uk/media/379438/soa-2018-19.pdf',
#  'south hams': 'https://www.southhams.gov.uk/media/1877/Statement-of-Accounts-2014-15/pdf/SOA_Booklet_2014-15_-_Audited.pdf?m=636380507194630000',
#  'teignbridge': 'https://www.teignbridge.gov.uk/media/8537/2018-19-final-statement-of-accounts-with-strata-adjustments.pdf',
#  'torridge': 'https://www.torridge.gov.uk/CHttpHandler.ashx?id=19566&p=0',
#  'west devon': 'https://www.westdevon.gov.uk/media/5296/Audited-Statement-of-Accounts-2018-19/pdf/WD_Audited_SOA_2018-19.pdf?m=637002041455230000',
#  'dorset ua': 'https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/shadow-dorset-council/shadow-dorset-council-agar-2018-19-declaration-of-no-accounts.pdf',
#  'bournemouth, christchurch and poole ua': 'https://www.bcpcouncil.gov.uk/About-the-council/Budgets-and-finance/Documents/annual-accounts/Borough-of-Poole-statement-of-annual-accounts-18-19.pdf',
#  'darlington ua': 'https://www.darlington.gov.uk/media/9416/annual-governance-statement-2018-19.pdf',
#  'durham ua': 'https://www.durham.gov.uk/media/30524/Statement-of-Accounts-2018-2019/pdf/StatementOfAccounts2018-19.pdf?m=637399235413470000',
#  'brighton & hove ua': 'https://www.brighton-hove.gov.uk/sites/default/files/migrated/article/inline/BHCC SoA 2018-19 final with signatures (Sept 19) published.pdf',
#  'east sussex': 'https://www.eastsussex.gov.uk/media/13904/statement-of-accounts-2018-19.pdf',
#  'eastbourne': 'https://www.lewes-eastbourne.gov.uk/access-to-information/financial-information/statement-of-accounts/?assetdet39e14ce8-bfa6-4bb1-a5b3-2c92d6811d83=284864',
#  'hastings': 'https://www.hastings.gov.uk/content/my_council/budgets_finance/budgets_finance/Hastings_Borough_Council_Budget_2018-19.pdf',
#  'lewes': 'https://www.lewes-eastbourne.gov.uk/access-to-information/financial-information/statement-of-accounts/?assetdet39e14ce8-bfa6-4bb1-a5b3-2c92d6811d83=284864',
#  'rother': 'https://www.rother.gov.uk/wp-content/uploads/2020/01/Copy_of_Budbook1819_Final.pdf',
#  'wealden': 'https://www.wealden.gov.uk/UploadedFiles/2018-19-Final-Accounts.pdf',
#  'southend-on-sea ua': [],
#  'thurrock ua': 'https://www.thurrock.gov.uk/sites/default/files/assets/documents/acco_2019_annual_accounts_v04.pdf',
#  'essex': 'https://assets.ctfassets.net/knkzaf64jx5x/6lZ4JUX3rIa8vk5FckubbQ/f8239eeb9baa6912c62adc853dfb0c9e/ORGANISATION_PLAN_18_19.pdf',
#  'basildon': 'https://www.basildon.gov.uk/media/9571/Basildon-Council-Audited-Annual-Financial-Report-2018-2019/pdf/Basildon_Council_-_Audited_Annual_Financial_Report_-_2018-2019.pdf?m=637002645323200000',
#  'braintree': 'https://www.braintree.gov.uk/directory-record/7668/statement-of-accounts-2018-2019',
#  'brentwood': [],
#  'castle point': 'https://www.castlepoint.gov.uk/download.cfm?doc=docm93jijm4n4285.pdf&ver=7212',
#  'chelmsford': 'https://www.chelmsford.gov.uk/_resources/assets/inline/full/0/3714593.pdf',
#  'colchester': 'https://cbccrmdata.blob.core.windows.net/noteattachment/CBC-Corporate-Statement-of-Accounts-StateofAcc%201819%20orig%20-%20FINAL%2031.07.2019.pdf',
#  'epping forest': [],
#  'harlow': 'https://www.harlow.gov.uk/sites/default/files/documents/Statement%20of%20accounts%202018%20to%202019%20%28DRAFT%29.pdf',
#  'maldon': 'https://www.maldon.gov.uk/downloads/file/18415/statement_of_accounts_final_2019-20',
#  'rochford': 'https://www.rochford.gov.uk/appointment-external-auditors-201819-202324',
#  'tendring': 'https://tdcdemocracy.tendringdc.gov.uk/documents/s15809/1%20Report%20to%20Cabinet%2018%20Jan%2019.pdf',
#  'uttlesford': 'https://www.uttlesford.gov.uk/media/6726/2018-19-Annual-Audit-Letter/pdf/Uttlesford_DC_AAL_201819(A).pdf?m=637514920791600000',
#  'gloucestershire': 'https://www.gloucestershire.gov.uk/media/2090998/final-consolidated-soa-2018-19.pdf',
#  'cheltenham': 'https://www.cheltenham.gov.uk/downloads/file/7597/final_audited_statement_of_accounts_-_201819',
#  'cotswold': 'https://www.cotswoldsaonb.org.uk/wp-content/uploads/2019/06/2018-19-ANNUAL-REVIEW-FINAL_SO_11-6-19.pdf',
#  'forest of dean': 'https://www.fdean.gov.uk/media/c5pb0zni/statement-of-accounts-2018-to-2019.pdf',
#  'gloucester': 'https://www.gloucestershire.gov.uk/media/2090998/final-consolidated-soa-2018-19.pdf',
#  'stroud': 'https://www.stroud.gov.uk/media/1070532/statement-of-accounts-2018-19.pdf',
#  'tewkesbury': 'https://tewkesburyborough-my.sharepoint.com/:f:/g/personal/website_tewkesburyborough_onmicrosoft_com/Ej27rw6w_cxDr7WkqR4iTHMBYPHj_AAFJjrKpg70k9LA4g?e=NItlDS',
#  'portsmouth ua': 'https://www.portsmouth.gov.uk/wp-content/uploads/2020/05/Portsmouth-City-Council-audit-closure-notice-2018-19.pdf',
#  'southampton ua': 'https://www.southampton.gov.uk/Images/Notice-of-appointment-of-auditor-to-Southampton-City-Council-from-2018_tcm63-403317.pdf',
#  'hampshire': 'https://documents.hants.gov.uk/finance/HCC-statementofaccounts2018-19-audited.pdf',
#  'basingstoke & deane': 'https://www.basingstoke.gov.uk/content/doclib/2487.pdf',
#  'east hampshire': 'https://www.easthants.gov.uk/statement-accounts-2018-19-pdf-87-mb',
#  'eastleigh': 'https://www.eastleigh.gov.uk/media/5240/2018-19-statement-of-accounts.pdf',
#  'fareham': 'http://www.fareham.gov.uk/PDF/about_the_council/AnnualGovernanceStatement1819.pdf',
#  'gosport': 'https://www.gosport.gov.uk/media/2102/Statement-of-Accounts-2018-2019/pdf/5_Final_Statement_of_Accounts_2018-19.pdf?m=637111614967170000',
#  'hart': 'https://www.hart.gov.uk/sites/default/files/4_The_Council/Policies_and_published_documents/Council_finances/HDC%20Budget%20book%20-%20Aug%202018.pdf',
#  'havant': 'https://www.havant.gov.uk/draft-statement-accounts-2019-20-pdf-18-mb',
#  'new forest': 'https://www.newforest.gov.uk/media/1025/Annual-Financial-Report-2019-20/pdf/statement_acs1920_excelerator_AUDITED_with_Audit_Opinion___AGS.pdf?m=637423408221800000',
#  'rushmoor': 'https://www.rushmoor.gov.uk/CHttpHandler.ashx?id=21352&p=0',
#  'test valley': 'https://www.testvalley.gov.uk/assets/attach/9151/Statement%20of%20Accounts%20in%20full%20-%202018-19.pdf',
#  'winchester': 'https://www.winchester.gov.uk/assets/attach/19942/Annual-Financial-Report-1819-V6.4.pdf',
#  'herefordshire ua': [],
#  'worcestershire': 'https://capublic.worcestershire.gov.uk/atoZ/?_ga=2.194771950.27594986.1593418457-1412071357.1579783701',
#  'bromsgrove': 'https://www.bromsgrove.gov.uk/media/4618836/Bromsgrove-DC-audit-opinion-2018-19.pdf',
#  'redditch': 'https://www.redditchbc.gov.uk/media/4623099/Redditch-BC-audit-opinion-2018-19-FINAL.pdf',
#  'worcester': 'https://capublic.worcestershire.gov.uk/atoZ/?_ga=2.194771950.27594986.1593418457-1412071357.1579783701',
#  'wychavon': [],
#  'wyre forest': [],
#  'malvern hills': [],
#  'hertfordshire': 'https://www.north-herts.gov.uk/sites/northherts-cms/files/Signed%20and%20Audited%20Statement%20of%20Accounts%202018-19.pdf',
#  'broxbourne': 'https://ex.broxbourne.gov.uk/sites/default/files/Documents/Finance/Completion%20of%20audit%20advert%202018-19.pdf',
#  'dacorum': 'http://www.dacorum.gov.uk/docs/default-source/finance-performance/statement-of-accounts-2018-19.pdf?sfvrsn=88a90a9e_2',
#  'east hertfordshire': 'https://eastherts.fra1.digitaloceanspaces.com/s3fs-public/2019-12/Letter%20of%20Representation%202018-19.pdf',
#  'hertsmere': 'https://www.hertsmere.gov.uk/Documents/11-Your-Council/How-the-council-works/Finance/Statement-of-Accounts/Statement-of-Accounts-2018-19.pdf',
#  'north hertfordshire': 'https://www.north-herts.gov.uk/sites/northherts-cms/files/Signed%20and%20Audited%20Statement%20of%20Accounts%202018-19.pdf',
#  'st albans': 'https://www.stalbans.gov.uk/sites/default/files/documents/publications/council/Financial%20Profile%202018-19.pdf',
#  'stevenage': [],
#  'three rivers': 'https://www.threerivers.gov.uk/download?id=45146',
#  'watford': [],
#  'welwyn hatfield': [],
#  'east riding of yorkshire ua': "javascript:__doPostBack('esctl_26765856$ctlAssetManager$flwBrowseAssets$console$consoleTable','itemclick,2,738836')",
#  'kingston upon hull ua': 'http://www.hull.gov.uk/sites/hull/files/media/Audit%20of%20Accounts%201819.pdf',
#  'north east lincolnshire ua': 'http://www.nelincs.co.uk/wp-content/uploads/2019/08/Statement-of-Accounts-2018-2019.pdf',
#  'north lincolnshire ua': 'https://www.northlincs.gov.uk/wp-content/uploads/2019/08/Statement-of-Accounts-2018-19.pdf',
#  'isle of wight ua': [],
#  'the medway towns ua': [],
#  'kent': 'https://www.kent.gov.uk/__data/assets/pdf_file/0004/93793/Statement-of-Accounts-2018-19.pdf',
#  'ashford': 'https://www.ashford.gov.uk/media/mpbfimac/u-website-documents-annual-governance-statement-annual-governanace-statement-2018-19.pdf',
#  'canterbury': [],
#  'dartford': [],
#  'dover': 'https://www.dover.gov.uk/Corporate-Information/Financial-Information/PDF/Statement-of-Accounts-2018-19.pdf',
#  'gravesham': [],
#  'maidstone': 'https://maidstone.gov.uk/__data/assets/pdf_file/0007/280564/Audited-Narrative-Report-2019.pdf',
#  'sevenoaks': 'https://www.sevenoaks.gov.uk/directory/15/annual_accounts/category/418',
#  'folkestone and hythe': 'https://folkestone-hythe.gov.uk/media/1023/Audited-Statement-of-Accounts-2018-19/pdf/FINAL_SoA_2018-19_(V2)_(Signed_with_Audit_Opinion).pdf?m=637057117859000000',
#  'swale': 'https://www.swale.gov.uk/assets/Finance/Statements-of-Account/2018-19/Summary-of-Accounts-2018-19.pdf',
#  'thanet': 'https://www.thanet.gov.uk/wp-content/uploads/2018/03/Port-and-Harbours-Report-2019-20.pdf',
#  'tonbridge & malling': [],
#  'tunbridge wells': 'https://tunbridgewells.gov.uk/__data/assets/pdf_file/0005/371732/Annual-Audit-Letter-2019.pdf',
#  'blackburn with darwen ua': 'http://www.blackburn.gov.uk/sites/default/files/media/pdfs/Statement of Accounts 2018-19.pdf',
#  'blackpool ua': 'https://www.blackpool.gov.uk/Your-Council/Transparency-and-open-data/Documents/Audited-statement-of-accounts-2018-19.pdf',
#  'lancashire': 'http://www.lancashire.gov.uk/media/911402/statement-of-accounts-2018-19.pdf',
#  'burnley': [],
#  'chorley': 'https://chorley.gov.uk/media/857/Delayed-audit-opinion-2019-20/pdf/Delayed_Audit_Opinion_2019-20_CBC.pdf?m=637475309518370000',
#  'fylde': 'https://new.fylde.gov.uk/wp-content/uploads/2020/12/2018-19-Fylde-BC-FINAL-ISA260-Report.pdf',
#  'hyndburn': [],
#  'south kesteven': 'http://www.southkesteven.gov.uk/CHttpHandler.ashx?id=22914&p=0',
#  'west lindsey': [],
#  'norfolk': 'https://www.norfolk.gov.uk/-/media/norfolk/downloads/what-we-do-and-how-we-work/budget-and-council-tax/statement-of-accounts/statement-of-accounts-2018-2019.pdf',
#  'breckland': 'https://www.breckland.gov.uk/media/17779/Annual-Audit-Letter-2019-20/pdf/20_Breckland_Council_Annual_Audit_Letter_-_18_December_20201.pdf?m=637469113775330000',
#  'broadland': 'https://www.broadland.gov.uk/download/downloads/id/5433/statement_of_accounts_2018_to_2019.pdf',
#  'great yarmouth': 'https://www.great-yarmouth.gov.uk/media/4428/Statement-of-Accounts-201819/pdf/Statement_of_Accounts_2018-19.pdf',
#  "king's lynn & west norfolk": [],
#  'north norfolk': 'https://www.north-norfolk.gov.uk/media/6475/audit-closure-notice-2018-19.pdf',
#  'norwich': 'https://www.norwich.gov.uk/downloads/file/5264/notice_of_completion_of_the_audit_2018-19',
#  'south norfolk': [],
#  'york ua': 'https://www.york.gov.uk/downloads/file/2236/cyc-statement-of-accounts-2018-to-2019',
#  'north yorkshire': 'https://www.northyorks.gov.uk/sites/default/files/fileroot/About%20the%20council/Spending/Public%20rights%20of%20inspection%20notice%20-2018-19.pdf',
#  'craven': 'https://www.cravendc.gov.uk/media/8708/audited-cdc-statement-workbook-2018-19-signed.pdf',
#  'hambleton': [],
#  'richmondshire': 'https://www.richmondshire.gov.uk/media/11094/statement-of-accounts-18-19-final.pdf',
#  'scarborough': 'https://www.scarborough.gov.uk/sites/scarborough.gov.uk/files/files/Statement-of-Accounts-2018-2019-Subject-to-Audit.pdf',
#  'harrogate': 'https://www.harrogate.gov.uk/cdn-cgi/l/email-protection#',
#  'ryedale': [],
#  'selby': 'https://www.selby.gov.uk/officer-decisions',
#  'northamptonshire': 'https://www.northamptonshire.gov.uk/councilservices/council-and-democracy/budgets-and-spending/Documents/Initial%20Public%20Inspection%20Notice%202019-20.pdf',
#  'corby': 'https://www.corby.gov.uk/council/open-data-and-transparency/council-budgets-spending/annual-accounts/statement-accounts-2018',
#  'daventry': 'https://www.daventrydc.gov.uk/EasySiteWeb/GatewayLink.aspx?alId=50851',
#  'east northamptonshire': 'https://www.east-northamptonshire.gov.uk/downloads/file/11292/public_notice_%E2%80%93_audit_of_accounts_201819',
#  'kettering': 'https://www.kettering.gov.uk/download/downloads/id/18668/statement_of_accounts_2018-19.pdf',
#  'northampton': 'https://www.northampton.gov.uk/download/downloads/id/11571/annual-governance-statement-201819.pdf',
#  'south northamptonshire': [],
#  'wellingborough': 'http://www.wellingborough.gov.uk/downloads/file/8657/annual_governance_statement_2018-19',
#  'northumberland ua': 'https://www.northumberland.gov.uk/NorthumberlandCountyCouncil/media/About-the-Council/Finance/Completion-of-Accounts-Advert.pdf',
#  'city of nottingham ua': 'https://www.nottinghaminsight.org.uk/d/a1uCEFc',
#  'nottinghamshire': 'https://www.nottinghamshire.gov.uk/media/2313928/ncc-accounts-auditedv3.pdf',
#  'ashfield': 'https://www.ashfield.gov.uk/media/8d854d5040b671d/ashfield-dc-aal-2018-19-v2.pdf',
#  'bassetlaw': 'https://data.bassetlaw.gov.uk/media/6807/201819-audited-statement-of-accounts.pdf',
#  'broxtowe': 'https://www.broxtowe.gov.uk/media/8182/public-inspection-of-accounts-notice-2019-20.pdf',
#  'gedling': [],
#  'mansfield': [],
#  'newark & sherwood': 'https://www.newark-sherwooddc.gov.uk/media/newarkandsherwood/imagesandfiles/finance/statementofaccounts/statementOfAccounts2018to19.pdf',
#  'rushcliffe': 'https://www.rushcliffe.gov.uk/media/1rushcliffe/media/documents/pdf/councilanddemocracy/Audited Statement of Accounts 2018-19.pdf',
#  'oxfordshire': 'https://www.oxfordshire.gov.uk/sites/default/files/file/council-tax-and-finance/AnnualAuditLetter2018-19.pdf',
#  'cherwell': 'https://www.cherwell.gov.uk/download/downloads/id/9522/2018-2019-annual-audit-letter.pdf',
#  'oxford': [],
#  'south oxfordshire': 'https://www.oxfordshire.gov.uk/sites/default/files/file/council-tax-and-finance/AnnualAuditLetter2018-19.pdf',
#  'vale of white horse': 'https://www.whitehorsedc.gov.uk/wp-content/uploads/sites/3/2020/12/19-VOWH-Final-signed-and-scanned-statement-of-accounts-1.pdf',
#  'west oxfordshire': 'https://www.westoxon.gov.uk/media/pwzhhekp/2019-to-2020-annual-audit-letter.pdf',
#  'telford and the wrekin ua': 'https://www.telford.gov.uk/downloads/download/2186/annual_accounts_and_reports_2018_-_2019',
#  'shropshire ua': 'https://www.shropshire.gov.uk/media/12724/annual-governance-statement-201819.pdf',
#  'somerset': 'https://wwwmedia.somerset.gov.uk/?democracy=grant-thornton-final-audit-certificate-2018-19',
#  'mendip': 'https://www.mendip.gov.uk/media/23380/Statement-of-Accounts-2018-19/pdf/Statement_of_Accounts_2018-19.pdf?m=637090835170570000',
#  'sedgemoor': 'https://www.sedgemoor.gov.uk/media/9518/Statement-of-Accounts-2019-20/pdf/SDC_Statement_of_Accounts_2019-20_with_audit_opinion.pdf?m=637481388760100000',
#  'south somerset': 'https://www.southsomerset.gov.uk/media/2514/statements-2018-19-audited-31072019-final-published.pdf',
#  'somerset west and taunton': 'https://www.somersetwestandtaunton.gov.uk/media/1765/taunton-deane-ags-2018-19.pdf',
#  'stoke-on-trent ua': 'https://www.stoke.gov.uk/directory_record/333555/draft_annual_governance_statement_2018-2019/category/355/accounts',
#  'staffordshire': 'https://www.staffordshire.gov.uk/Your-council-and-democracy/Council-tax-and-finance/Documents/Statement-of-Accounts-2018-2019v2.pdf',
#  'cannock chase': 'https://www.cannockchasedc.gov.uk/sites/default/files/statement_of_accounts_19-20_new.pdf',
#  'east staffordshire': 'https://www.eaststaffsbc.gov.uk/sites/default/files/docs/finance/Statement-of-Accounts-2018-19.pdf',
#  'lichfield': 'https://www.lichfielddc.gov.uk/downloads/file/1251/statement-of-accounts-2018-19',
#  'newcastle-under-lyme': 'https://www.newcastle-staffs.gov.uk/sites/default/files/IMCE/YourCouncil/Accounts/Statement%20of%20Accounts%202018-19.pdf',
#  'south staffordshire': 'https://www.sstaffs.gov.uk/doc/181936/name/Statement%20of%20Accounts%202020.pdf/',
#  'nuneaton & bedworth': [],
#  'rugby': 'https://www.rugby.gov.uk/downloads/file/2567/audit_report_20182019',
#  'stratford-on-avon': [],
#  'warwick': 'https://www.warwickdc.gov.uk/downloads/download/1173/statement_of_accounts_201819',
#  'west sussex': 'https://www.westsussex.gov.uk/media/13011/annual_report_2018_19.pdf',
#  'adur': 'https://www.adur-worthing.gov.uk/media/Media,154060,smxx.pdf',
#  'arun': 'https://www.arun.gov.uk/download.cfm?doc=docm93jijm4n11952.pdf&ver=11952',
#  'chichester': 'https://www.chichester.gov.uk/media/32310/Annual-Audit-letter-2018-19/pdf/Annual_Audit_Letter_2018-19.pdf',
#  'crawley': 'https://crawley.gov.uk/sites/default/files/documents/PUB352812.pdf',
#  'horsham': 'https://www.horsham.gov.uk/__data/assets/pdf_file/0019/90118/Website-Audited-Statement-of-Accounts-2019-20.pdf',
#  'mid sussex': 'https://www.midsussex.gov.uk/media/1734/corporate-plan-and-budget-2018-19.pdf',
#  'worthing': 'https://www.adur-worthing.gov.uk/media/Media,154060,smxx.pdf',
#  'swindon ua': [],
#  'wiltshire ua': 'https://www.wiltshire.gov.uk/media/5190/Statement-of-Accounts-2018-2019/pdf/Statement_of_Accounts_2018-2019.pdf?m=637424200978970000',
#  'isles of scilly': 'https://www.scilly.gov.uk/sites/default/files/document/council/CIOS%20Statement%20of%20Accounts%202018-19%20Final%20to%20Full%20Council%20with%20opinion_0.pdf',
#  'bolton': [],
#  'bury': 'https://www.bury.gov.uk/CHttpHandler.ashx?id=20110&p=0',
#  'manchester': 'https://www.manchester.gov.uk/downloads/download/7084/audited_accounts_2018-19',
#  'oldham': 'https://www.oldham.gov.uk/downloads/file/5705/audit_certificate_2018-19',
#  'rochdale': 'http://www.legislation.gov.uk/ukpga/1998/18/contents',
#  'salford': 'https://www.salford.gov.uk/media/394051/annual-governance-statement-2018-19.pdf',
#  'stockport': 'https://assets.ctfassets.net/ii3xdrqc6nfw/3z7goshow0IcYWaEk6EYek/af80f0a857a553bf9441e506b56345ec/Notice_of_Appointment_of_Auditor_2018_to_2019.pdf',
#  'tameside': 'https://www.tameside.gov.uk/TamesideMBC/media/earlyyears/S251-Budget-2018-19-Early-Years-Table.pdf',
#  'trafford': [],
#  'wigan': 'https://www.wigan.gov.uk/Council/Performance-and-Spending/Statement-of-Accounts/Statement-of-accounts-2018-2019.aspx',
#  'knowsley': 'https://www.knowsley.gov.uk/knowsleycouncil/media/Documents/Statement-of-Accounts-2018-19.pdf',
#  'liverpool': 'https://liverpool.gov.uk/media/1358131/statement-of-accounts-2018-19.pdf',
#  'st helens': 'https://www.sthelens.gov.uk/media/10548/audit-findings-report-201819-final.pdf',
#  'sefton': 'https://www.sefton.gov.uk/media/3281/statement-of-accounts-2018-2019-post-ag.pdf',
#  'wirral': 'https://www.wirral.gov.uk/sites/default/files/all/About the council/Performance and spending/Accounts/Statement%20of%20Accounts%202018-19.pdf',
#  'barnsley': 'https://www.barnsley.gov.uk/media/18000/executive-summary-accounts-201920.pdf',
#  'doncaster': [],
#  'rotherham': 'https://www.rotherham.gov.uk/downloads/file/1918/spend-over-500-february-2020',
#  'sheffield': [],
#  'gateshead': 'https://www.gateshead.gov.uk/media/13878/Statement-of-accounts-2018-19/pdf/Statement_of_Accounts_2018-19_Website.pdf?m=637001844107600000',
#  'newcastle upon tyne': 'https://www.newcastle.gov.uk/sites/default/files/annual report and accounts/Annual Report & Accounts 2018-19 - 30-07-19 signed web version.pdf',
#  'north tyneside': 'https://my.northtyneside.gov.uk/sites/default/files/web-page-related-files/North%20Tyneside%20Council%20Issue%20of%20Certificate%202018-19%20Post%20WGA.pdf',
#  'south tyneside': 'https://www.southtyneside.gov.uk/media/40799/Financial-Statements-2018-2019/pdf/Statement_for_Publication_2018_19_audited.pdf',
#  'sunderland': 'https://www.sunderland.gov.uk/article/16251/2018-2019',
#  'birmingham': [],
#  'coventry': [],
#  'dudley': [],
#  'sandwell': [],
#  'solihull': 'https://www.solihull.gov.uk/sites/default/files/migrated/PerformanceAndSpending_Accounting-Statement-2018-19.pdf',
#  'walsall': 'https://go.walsall.gov.uk/Portals/0/Uploads/AboutTheCouncil/Notice of Conclusion of Audit 2019-20_1.pdf?ver=2021-02-18-153323-460',
#  'wolverhampton': 'https://www.wolverhampton.gov.uk/sites/default/files/2019-08/SOA%202018-19.pdf',
#  'bradford': [],
#  'calderdale': [],
#  'kirklees': 'https://www.kirklees.gov.uk/beta/delivering-services/pdf/revenue-budget-2018-20.pdf',
#  'leeds': [],
#  'wakefield': 'http://www.wakefield.gov.uk/Statement of accounts/statement-of-accounts.pdf',
#  'city of london': [],
#  'camden': 'https://www.camden.gov.uk/documents/20142/188956790/Draft+Statement+of+Accounts+2019-20+signed.pdf/27693889-970e-34e4-cd4f-f8fab4cfa5a8?t=1591018628905',
#  'greenwich': [],
#  'hackney': 'https://drive.google.com/file/d/1tQAZ5KwWE2LwRHcW6zJe3IVb0crE4Wmu/view?usp=sharing',
#  'hammersmith & fulham': 'https://www.lbhf.gov.uk/sites/default/files/section_attachments/2018-19_lbhf_soa_master_2019-07-31_1655_signed_audited.pdf',
#  'islington': [],
#  'kensington & chelsea': 'https://www.rbkc.gov.uk/sites/default/files/atoms/files/Report%20to%20those%20charged%20with%20governance%20%28ISA%20260%29%202018-19.pdf',
#  'lambeth': 'https://www.lambeth.gov.uk/sites/default/files/ec-annual-governance-statement-2018-19.pdf',
#  'lewisham': 'https://lewisham.gov.uk/-/media/files/imported/statementofaccounts1819.ashx',
#  'southwark': 'https://www.southwark.gov.uk/assets/attach/28605/Southwark-Council-Audit-Certificate-2018-19.pdf',
#  'tower hamlets': [],
#  'wandsworth': 'https://www.wandsworth.gov.uk/media/5283/statement_of_accounts_2018_19.pdf',
#  'westminster': 'https://www.westminster.gov.uk/annual-accounts/2018-2019-annual-accounts',
#  'barking & dagenham': 'https://www.lbbd.gov.uk/sites/default/files/attachments/Budget-book-2018-19.pdf',
#  'barnet': 'http://www.barnet.gov.uk/sites/default/files/soa_30092019.pdf',
#  'bexley': 'https://www.bexley.gov.uk/sites/default/files/2021-01/Draft-Statement-of-Accounts-2018-to-2019.pdf',
#  'brent': [],
#  'bromley': [],
#  'croydon': [],
#  'ealing': [],
#  'enfield': 'https://new.enfield.gov.uk/services/your-council/statement-of-accounts/final-audited-statement-of-accounts-2018-19.pdf',
#  'haringey': 'https://www.haringey.gov.uk/sites/haringeygovuk/files/haringey_statement_of_accounts_2018-19.pdf',
#  'harrow': 'https://www.harrow.gov.uk/downloads/file/26667/audit-certificate-2018-19',
#  'havering': 'https://www.havering.gov.uk/download/downloads/id/4040/201819_-_independent_auditors_certificate.pdf',
#  'hillingdon': 'https://archive.hillingdon.gov.uk/media/41489/201819-Accounts/pdf/18-19_London_Borough_of_Hillingdon_Statement_of_Accounts.pdf',
#  'hounslow': 'https://www.hounslow.gov.uk/download/downloads/id/1686/notice_of_appointment_of_auditor_201819.pdf',
#  'kingston upon thames': [],
#  'merton': 'https://www.merton.gov.uk/assets/Documents/Statement%20of%20Accounts%20for%20Website%20and%20Print%20v13.pdf',
#  'newham': 'https://www.newham.gov.uk/downloads/file/476/statementofaccounts201819',
#  'redbridge': 'https://www.redbridge.gov.uk/media/7079/2018-19-audited-statement-of-accounts.pdf',
#  'richmond upon thames': 'https://www.richmond.gov.uk/media/18237/statement_of_accounts_2018_19.pdf',
#  'sutton': 'https://www.sutton.gov.uk/download/downloads/id/4001/audited_statement_of_accounts_2018-19.pdf',
#  'waltham forest': 'https://www.walthamforest.gov.uk/content/council-finances#collapse-1-2',
#  'greater london authority': 'https://www.london.gov.uk/sites/default/files/notice_of_2018-19_public_inspection_of_accounts_.pdf',
#  'east london waste authority': 'https://eastlondonwaste.gov.uk/wp-content/uploads/statement-of-accounts-ELWA-Annual-Financial-Statements-2018-19-Audited-Final.pdf',
#  'merseyside waste disposal authority': 'http://www.merseysidewda.gov.uk/wp-content/uploads/2019/05/SoA-2018-19-Unaudited-Accounts-30.05.19.pdf',
#  'north london waste authority': 'https://www.nlwa.gov.uk/sites/default/files/inline-files/nlwa-statement-of-accounts-2018-19-final.pdf',
#  'western riverside waste authority': 'https://wrwa.gov.uk/wp-content/uploads/2020/03/Signed-financial-statements-WRWA-31-March-2019.pdf',
#  'west london waste authority': 'https://westlondonwaste.gov.uk/download/15031/',
#  'west midlands combined authority': 'https://www.wmca.org.uk/media/3278/wmca_itapf-2018-19-audited-accounts.pdf',
#  'greater manchester combined authority': [],
#  'liverpool city region combined authority': 'https://www.liverpoolcityregion-ca.gov.uk/wp-content/uploads/LCRCA-Statement-of-Accounts-2018-19.pdf',
#  'sheffield city region combined authority': [],
#  'the west yorkshire combined authority': 'https://www.westyorks-ca.gov.uk/media/2620/wyca-auditors-report-2018_19_final.pdf',
#  'west of england combined authority': 'https://www.westofengland-ca.gov.uk/wp-content/uploads/2018/01/Item-10-WECA-Budget-Setting-Report-2018-19.pdf',
#  'tees valley combined authority': 'https://teesvalley-ca.gov.uk/wp-content/uploads/2019/12/Notice-of-Audit-Completion-18-19.pdf',
#  'cambridgeshire and peterborough combined authority': [],
#  'north east combined authority': 'https://northeastca.gov.uk/wp-content/uploads/2019/07/NECA-Statement-of-Accounts-2018-19.pdf',
#  'north of tyne combined authority': [],
# Got council: wandsworth (5 links found)
# Got council: westminster (1 links found)
# Got council: barking & dagenham (6 links found)
# Got council: barnet (2 links found)
# Got council: bexley (3 links found)
# Got council: brent (0 links found)
# Got council: bromley (3 links found)
# Got council: croydon (0 links found)
# Got council: ealing (0 links found)
# Got council: enfield (3 links found)
# Got council: haringey (6 links found)
# Got council: harrow (5 links found)
# Got council: havering (1 links found)
# Got council: hillingdon (8 links found)
# Got council: hounslow (1 links found)
# Got council: kingston upon thames (0 links found)
# Got council: merton (7 links found)
# Got council: newham (2 links found)
# Got council: redbridge (9 links found)
# Got council: richmond upon thames (8 links found)
# Got council: sutton (4 links found)
# Got council: waltham forest (12 links found)
# Got council: greater london authority (18 links found)
# Got council: east london waste authority (3 links found)
# Got council: merseyside waste disposal authority (2 links found)
# Got council: north london waste authority (4 links found)
# Got council: western riverside waste authority (13 links found)
# Got council: west london waste authority (5 links found)
# Got council: west midlands combined authority (15 links found)
# Got council: greater manchester combined authority (3 links found)
# Got council: liverpool city region combined authority (18 links found)
# Got council: sheffield city region combined authority (0 links found)
# Got council: the west yorkshire combined authority (10 links found)
# Got council: west of england combined authority (10 links found)
# Got council: tees valley combined authority (6 links found)
# Got council: cambridgeshire and peterborough combined authority (3 links found)
# Got council: north east combined authority (6 links found)
# Got council: north of tyne combined authority (1 links found)
# Got council: dartmoor national park authority (6 links found)
# Got council: exmoor national park authority (9 links found)
# Got council: lake district national park authority (14 links found)
# Got council: north york moors national park authority (7 links found)
# Got council: northumberland national park authority (7 links found)
# Got council: peak district national park authority (13 links found)
# Got council: yorkshire dales national park authority (21 links found)
# Got council: the broads authority (23 links found)
# Got council: new forest national park authority (5 links found)
# Got council: south downs national park authority (1 links found)
# Got council: lee valley regional park authority (0 links found)

# %%
countLinks(st_17_18)
countLinks(st_17_18_checked)
# Out:
# 	LAs with 0 links: 87
# 	LAs with 0 links: 87

# %%
# Checking statements and getting single links.
st_17_18_checked = copy.deepcopy(st_17_18)
st_17_18_checked = checkAllStatements(st_17_18_checked, '2017', '2018')

st_18_19_checked = copy.deepcopy(st_18_19)
st_18_19_checked = checkAllStatements(st_18_19_checked, '2018', '2019')

st_19_20_checked = copy.deepcopy(st_19_20)
st_19_20_checked = checkAllStatements(st_19_20_checked, '2019', '2020')

# %%
print("\nCounts before checks 2017 - 2018 (# LA):")
countLinks(st_17_18)

print("\nCounts after checks 2017 - 2018 (# LA):")
countLinks(st_17_18_checked)

print("\n\n")


print("\nCounts before checks 2018 - 2019 (# LA):")
countLinks(st_18_19)

print("\nCounts after checks 2018 - 2019 (# LA):")
countLinks(st_18_19_checked)

print("\n\n")

print("\nCounts before checks 2019 - 2020 (# LA):")
countLinks(st_19_20)

print("\nCounts after checks 2019 - 2020 (# LA):")
countLinks(st_19_20_checked)
# Out:
# Counts before checks 2017 - 2018 (# LA):
# 	LAs with 0 links: 50
#
# Counts after checks 2017 - 2018 (# LA):
# 	LAs with 0 links: 101
#
#
#
#
# Counts before checks 2018 - 2019 (# LA):
# 	LAs with 0 links: 37
#
# Counts after checks 2018 - 2019 (# LA):
# 	LAs with 0 links: 70
#
#
#
#
# Counts before checks 2019 - 2020 (# LA):
# 	LAs with 0 links: 27
#
# Counts after checks 2019 - 2020 (# LA):
# 	LAs with 0 links: 31

# %%
import json

def save_statements(statements, filename):
    filename = filename
    with open(filename, 'w') as f:
        f.write(json.dumps(statements))

# save_statements(st_17_18_checked, 'st_17_18')
        
def load_statements(statements, filename):
    with open(filename) as f:
        pet = json.loads(f.read())
    return statements

# %%
# Save the statements (json-like documents)
save_statements(st_17_18_checked, 'st_17_18')
save_statements(st_18_19_checked, 'st_18_19')
save_statements(st_19_20_checked, 'st_19_20')

# to load: e.g. st_17_18_test = load_statements(st_17_18_checked, 'st_17_18')

# %%
# tables = tabula.read_pdf(urls['Spelthorne'], pages = "all", multiple_tables = True)
#tables[-25][tables[-25].apply(lambda row: row.astype(str).str.contains('Current Assets' and 'Current Liabilities').any(), axis=1)]

def getTables(statements, authority_idx):
    
    url = statements[councilLinks_df.index[authority_idx]]
    print(url)
    
    if url == []:
        return 
    
    tables = tabula.read_pdf(url, pages = 'all', multiple_tables = True)
    
    print("There are {} tables for {}".format(len(tables), councilLinks_df.index[authority_idx]))
    
    newTables = list()

    for i in range(len(tables)):

        terms1 = tables[i][tables[i].apply(lambda row: \
                                          row.astype(str).str.contains('Current Assets' \
                                                                       and 'Current Liabilities' \
                                                                       and 'Long term Liabilities'\
                                                                       and 'Long term Assets', \
                                                                       flags=re.IGNORECASE,
                                                                       regex = True
                                                                      ).any(), axis=1)]

        terms2 = tables[i][tables[i].apply(lambda row: \
                                          row.astype(str).str.contains('Current Assets' \
                                                                       and 'Current Liabilities' \
                                                                       and 'Long-term Liabilities'\
                                                                       and 'Long-term Assets', \
                                                                       flags=re.IGNORECASE,
                                                                       regex = True
                                                                      ).any(), axis=1)]
        
        if (terms1.shape[0] != 0) or (terms2.shape[0] != 0):
            newTables.append(tables[i])
    
    
    print("\n{} tables that might be of interest".format(len(newTables)))
    
    return newTables

# %%
test_all_tables  = getTables(st_18_19_checked,2)
# Out:
# https://www.southglos.gov.uk//documents/Audited-Annual-Financial-Report-201819.pdf
# There are 97 tables for south gloucestershire ua
#
# 2 tables that might be of interest

# %%
test_all_tables[0]
# Out:
#      01 April   31 March                     Unnamed: 0 31 March.1  Note
# 0        2017       2018                            NaN       2019   NaN
# 1    Restated   Restated                            NaN        NaN   NaN
# 2       £'000      £'000                            NaN      £'000   NaN
# 3     797,477    854,992  Property, Plant and Equipment    895,264  14.0
# 4         621        493                Heritage Assets        493   NaN
# 5       5,073      5,351            Investment Property     18,556  17.0
# 6         900      1,290              Intangible Assets      1,702   NaN
# 7      15,323      7,115           Assets Held for Sale        945  17.0
# 8       7,719      4,709          Long term Investments     34,338  15.0
# 9       1,442      1,804              Long Term Debtors      2,884   NaN
# 10    828,555    875,754               Long Term Assets    954,182   NaN
# 11     67,394     77,877         Short Term Investments     72,463  15.0
# 12        613        654                    Inventories        660   NaN
# 13     33,508     36,588             Short Term Debtors     33,790  19.0
# 14     46,649     37,909      Cash and Cash Equivalents     14,094  16.0
# 15    148,164    153,028                 Current Assets    121,007   NaN
# 16    (1,627)    (1,668)           Short Term Borrowing    (1,663)   NaN
# 17   (12,609)   (22,864)             Current Provisions   (20,745)  20.0
# 18   (86,755)   (87,686)           Short Term Creditors   (92,470)  18.0
# 19  (100,991)  (112,218)            Current Liabilities  (114,878)   NaN
# 20    (2,871)    (2,531)                     Provisions    (2,425)  20.0
# 21  (122,683)  (122,235)            Long Term Borrowing  (121,788)  15.0
# 22  (383,520)  (351,521)    Other Long Term Liabilities  (412,477)  21.0
# 23  (509,074)  (476,287)          Long Term Liabilities  (536,690)   NaN
# 24    366,654    440,277                     Net Assets    423,621   NaN
# 25  (112,384)  (112,692)                Usable Reserves  (126,436)   NaN
# 26  (254,270)  (327,585)              Unusable Reserves  (297,185)  22.0
# 27  (366,654)  (440,277)                 Total Reserves  (423,621)   NaN

# %% [markdown]
# # Code dump

# %%
# import json

# def save_pet(pet):
#     filename = <Whatever filename you want>
#     with open(filename, 'w') as f:
#         f.write(json.dumps(pet))

# def load_pet(filename):
#     with open(filename) as f:
#         pet = json.loads(f.read())
#     return pet

# %%
# urls = dict({
#     'Spelthorne': 'https://www.spelthorne.gov.uk/media/23068/Draft-Statement-of-Accounts-2019-20/pdf/SoA_2019-20_100920_update1.pdf?m=637353494717970000',
#     'Nottingham': 'https://www.nottinghaminsight.org.uk/d/aaCFHALE'})

# %%
# # List all pdfs from a url.
# def findStatements(council, yearL, yearH, pdfs = []):  
    
#     councilLink = councilLinks_df.loc[council, ['Link']][-1]
                
#     #print("Council link:", councilLink)
    
#     session = requests.Session()
#     # This is needed for non-responsive links. Retry 3 time before moving on.
#     retry = Retry(connect=3, backoff_factor=0.5) 
#     adapter = HTTPAdapter(max_retries=retry)
#     session.mount('http://', adapter)
#     session.mount('https://', adapter)
#     response = session.get(councilLink, verify = False)
    
#     soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True)) # parse_only=SoupStrainer('a', href = True)     

# #     term1 = 'statement'
# #     term2 = 'accounts'
# #     substrings_v1 = (term1, term2, yearL, yearH)
# #     substrings_v2 = (term1, term2, yearL, yearH[2:])
# #     substrings_v3 = (term1, term2, yearL[2:], yearH[2:])

#     # Different combinations of years
#     # Would be nice to get a nice regex here.
#     substrings_v1 = [yearL, yearH]
#     substrings_v2 = [yearL, yearH[2:]]
#     substrings_v3 = [yearL[2:], yearH[2:]]
#     substrings_v4 = [yearL + yearH]
#     substrings_v5 = [yearL + yearH[2:]]
#     allSubstrings = [substrings_v1, substrings_v2, substrings_v3, substrings_v4, substrings_v5]
    
#     # Find all files containing 'pdf'
#     for link in soup.select("a[href*='pdf']"):
        
#         if conditions(allSubstrings, link, council):
            
#             # Join 'base' link of council with link for statement.
#             fullLink = urllib.parse.urljoin(councilLink, link['href'])
#             #print("PDF link:", fullLink)
                
#             # Add link to pdfs.    
#             pdfs.append(fullLink)    
# #             print(pdfs)

#     # If none found above, look at all files containing 'download'
#     if pdfs == []:
#         for link in soup.select("a[href*='download']"):
#             if conditions(allSubstrings, link):

#                 # Join 'base' link of council with link for statement.
#                 fullLink = urllib.parse.urljoin(councilLink, link['href'])
#                 #print("PDF link:", fullLink)

#                 # Add link to pdfs.    
#                 pdfs.append(fullLink)    
# #                 print(pdfs)
            
#     # Some councils have statements for different years
#     # on different webpages. If this is the case, figure out
#     # the relevant page, and call findStatements recurseively. 
#     if pdfs == []:
        
#         if len(soup.select("a[href*='{}-{}']".format(yearL,yearH))) == 0:
#             yearH = yearH[2:]
            
#             if len(soup.select("a[href*='{}-{}']".format(yearL,yearH))) == 0:
#                 yearL = yearL[2:]
            

#         for link in soup.select("a[href*='{}-{}']".format(yearL,yearH)):
#             #print("New council link (relavant year)", link['href'])

#             newLink = urllib.parse.urljoin(councilLink, link['href'])
#             findStatements(newLink, yearL, yearH, pdfs)

#     # Some of the accounts aren't actually pdf files
#     # So looking at the description of the file as opposed to
#     # the actual file extention. 
#     if pdfs == []:
#         #print('Not a pdf')
#         for link in soup.find_all('a', string = re.compile("pdf", re.IGNORECASE)):
#             fullLink = urllib.parse.urljoin(councilLink, link['href'])
#             pdfs.append(fullLink)
#             break
    
#     # If all else fails, just get all the pdfs.
#     if pdfs == []:
#         for link in soup.select("a[href*='.pdf']"):
#             # Join 'base' link of council with link for statement.
#             fullLink = urllib.parse.urljoin(councilLink, link['href'])
#             #print("PDF link:", fullLink)
                
#             # Add link to pdfs.    
#             pdfs.append(fullLink)  
        
            
#     return pdfs

# %%
# councilLink = 'https://www.centralbedfordshire.gov.uk/info/27/about_your_council/178/annual_accounts_fees_and_charges_budget_statements_and_budget_books'

# yearL = '2014'
# yearH = '2015'

# session = requests.Session()
# # This is needed for non-responsive links. Retry 3 time before moving on.
# retry = Retry(connect=3, backoff_factor=0.5) 
# adapter = HTTPAdapter(max_retries=retry)
# session.mount('http://', adapter)
# session.mount('https://', adapter)
# response = session.get(councilLink, verify = False)

# soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True))


# substrings_v1 = [yearL, yearH]
# substrings_v2 = [yearL, yearH[2:]]
# substrings_v3 = [yearL[2:], yearH[2:]]
# substrings_v4 = [yearL + yearH]
# substrings_v5 = [yearL + yearH[2:]]
# allSubstrings = [substrings_v1, substrings_v2, substrings_v3, substrings_v4, substrings_v5]

# for link in soup.select("a"):
#     if link.has_attr('href'):
# #     if conditions(allSubstrings, link):
#         print(link.text)

# %%
# Accessible links

# for council in councilLinks_df.iterrows():
#     print(councilLinks_df.loc[council[0]]['Link'])

# %%
# councilLinks_df.loc['south gloucestershire ua']['Link']
# # bla = {}
# # headers = {'User-Agent': 'Mozilla/5.0'}
# # councilLink = councilLinks_df.loc['south gloucestershire ua']['Link']
# allSubstrings = makeSearchTerms('2018', '2019', other = ['accounts'])
# # response = requests.get(councilLinks_df.loc['south gloucestershire ua']['Link'], 
# #                         timeout = 10,
# #                         headers=headers)

# # soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True))
# bla = {}
# soup = accessLink(councilLink)

# # Find all files containing 'pdf'
# for link in soup.select("a[href*='pdf']"):

#     if conditions(allSubstrings, link):
#         print(allSubstrings)
# #             print(link)

#         addLink(bla, councilLink, link)
    
# bla
# bla == {}
