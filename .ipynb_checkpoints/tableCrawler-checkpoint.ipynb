# %%
import google # https://pypi.org/project/google/#files
from googlesearch import search 
import pandas as pd
import tabula
import regex as re
import requests
from urllib.parse import urljoin
from bs4 import BeautifulSoup, SoupStrainer
import httplib2
import validators
import urllib.parse
import time
import warnings
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import sys

warnings.filterwarnings(action='ignore')

sys.setrecursionlimit(100)
# More on the google module here:
#https://python-googlesearch.readthedocs.io/en/latest/index.html#module-googlesearch

# An alternative here maybe:
# https://github.com/Nv7-GitHub/googlesearch/blob/master/googlesearch/__init__.py

# %%
# Get links hosting each LAs account statments.
def getLinks(names):
    
    # Empty list for saving links.
    links = []
    
    # Initialize search number (for pausing after a number of searches)
    searchNum = 0
    
    for council in names:
        
        # Increment search number by 1
        searchNum += 1
        print(searchNum)
        
        # Search terms (on query/council)
        query = r'{} statement of accounts "gov.uk"'.format(council)
        
        # Google search using 'query' above and save as object.
        queryObj = search(query, tld = 'com', stop = 1)
        
        # Quick and dirty way of getting something from a generator object.
        for j in queryObj:
            links.append(j)
        
        # Add a pause to the search every 30th term to avoid 'Too Many Requests'
        if searchNum%30 == 0:
            time.sleep(1000)
        
        
    return links

# %%
def conditions(subStrVers, link, council):
    '''
    Checks if all elements of a list (of strings) are present in a string (link).
    subStrVers is a list of lists, so that different versions of the lists can be checked.
    Makes more sense after looking at findStatements() below.
    
    Input: 
        subStrVers - a list of lists.
        link - a string. 
    
    Outputs True if conditions are satisfied, False otherwise.
    '''
    satisfied = False
    
    # Search in link name.
    for ss in subStrVers:
        if all(s in link['href'].lower() for s in ss):
            satisfied = True
            break
    
    # If not in link name, search in file name/descriptions.
    for ss in subStrVers:
        if all(s in link.text.lower() for s in ss):
            satisfied = True
            break
            
    return satisfied        





# List all pdfs from a url.
def findStatements(council, yearL, yearH, pdfs = []):  
    
    councilLink = councilLinks_df.loc[council, ['Link']][-1]
                
    #print("Council link:", councilLink)
    
    session = requests.Session()
    # This is needed for non-responsive links. Retry 3 time before moving on.
    retry = Retry(connect=3, backoff_factor=0.5) 
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    response = session.get(councilLink, verify = False)
    
    soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True)) # parse_only=SoupStrainer('a', href = True)     

#     term1 = 'statement'
#     term2 = 'accounts'
#     substrings_v1 = (term1, term2, yearL, yearH)
#     substrings_v2 = (term1, term2, yearL, yearH[2:])
#     substrings_v3 = (term1, term2, yearL[2:], yearH[2:])

    # Different combinations of years
    # Would be nice to get a nice regex here.
    substrings_v1 = [yearL, yearH]
    substrings_v2 = [yearL, yearH[2:]]
    substrings_v3 = [yearL[2:], yearH[2:]]
    substrings_v4 = [yearL + yearH]
    substrings_v5 = [yearL + yearH[2:]]
    allSubstrings = [substrings_v1, substrings_v2, substrings_v3, substrings_v4, substrings_v5]
    
    # Find all files containing 'pdf'
    for link in soup.select("a[href*='pdf']"):
        
        if conditions(allSubstrings, link, council):
            
            # Join 'base' link of council with link for statement.
            fullLink = urllib.parse.urljoin(councilLink, link['href'])
            #print("PDF link:", fullLink)
                
            # Add link to pdfs.    
            pdfs.append(fullLink)    
#             print(pdfs)

    # If none found above, look at all files containing 'download'
    if pdfs == []:
        for link in soup.select("a[href*='download']"):
            if conditions(allSubstrings, link):

                # Join 'base' link of council with link for statement.
                fullLink = urllib.parse.urljoin(councilLink, link['href'])
                #print("PDF link:", fullLink)

                # Add link to pdfs.    
                pdfs.append(fullLink)    
#                 print(pdfs)
            
    # Some councils have statements for different years
    # on different webpages. If this is the case, figure out
    # the relevant page, and call findStatements recurseively. 
    if pdfs == []:
        
        if len(soup.select("a[href*='{}-{}']".format(yearL,yearH))) == 0:
            yearH = yearH[2:]
            
            if len(soup.select("a[href*='{}-{}']".format(yearL,yearH))) == 0:
                yearL = yearL[2:]
            

        for link in soup.select("a[href*='{}-{}']".format(yearL,yearH)):
            #print("New council link (relavant year)", link['href'])

            newLink = urllib.parse.urljoin(councilLink, link['href'])
            findStatements(newLink, yearL, yearH, pdfs)

    # Some of the accounts aren't actually pdf files
    # So looking at the description of the file as opposed to
    # the actual file extention. 
    if pdfs == []:
        #print('Not a pdf')
        for link in soup.find_all('a', string = re.compile("pdf", re.IGNORECASE)):
            fullLink = urllib.parse.urljoin(councilLink, link['href'])
            pdfs.append(fullLink)
            break
    
    # If all else fails, just get all the pdfs.
    if pdfs == []:
        for link in soup.select("a[href*='.pdf']"):
            # Join 'base' link of council with link for statement.
            fullLink = urllib.parse.urljoin(councilLink, link['href'])
            #print("PDF link:", fullLink)
                
            # Add link to pdfs.    
            pdfs.append(fullLink)  
        
            
    return pdfs

# %%
findStatements(council = 'adur', yearL = '2017', yearH = '2018')
# Out:
# ['https://www.adur-worthing.gov.uk/media/Media,149557,smxx.pdf',
#  'https://www.adur-worthing.gov.uk/media/Media,149558,smxx.pdf',
#  'https://www.adur-worthing.gov.uk/media/Media,154692,smxx.pdf',
#  'https://www.adur-worthing.gov.uk/media/Media,154693,smxx.pdf']

# %%
# Get list of all councils
councilNames = pd.read_csv('/Users/munchausend/GoogleDrive/MSc/Assignments/ADS/MHCLG/Data/councilNames.csv')
councilNames = councilNames['x'].str.lower()

# %%
# testLink = getLinks(councilNames[:2])
# testLink

# # Get link to page where account statements will
# # be for each council.
# councilLinks = getLinks(councilNames)

# # Save as df -> csv 
# dfLinks = pd.DataFrame(data = {"Councils": councilNames, "Link": councilLinks})
# dfLinks.to_csv("./councilLinks.csv", sep = ',', index = False)

# Load csv
councilLinks_df = pd.read_csv('./councilLinks.csv')
councilLinks = councilLinks_df['Link'] 
councilLinks_df.set_index('Councils', inplace = True)

print(len(councilLinks))
print(len(councilNames))

# They have the same length, but we don't know 
# if we actually got one link per LA 
# e.g. some searches might've returned news articles or
# other stuff.

# It's not straighforward to check, so will go ahead
# with the assumption that we got all relevant links
# and see if there's any anomalies when getting the 
# PDFs from the pages.
# Out:
# 383
# 383

# %%
councilLink = councilLinks[0]

yearL = '2017'
yearH = '2018'

session = requests.Session()
# This is needed for non-responsive links. Retry 3 time before moving on.
retry = Retry(connect=3, backoff_factor=0.5) 
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)
response = session.get(councilLink, verify = False)

soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True))


substrings_v1 = [yearL, yearH]
substrings_v2 = [yearL, yearH[2:]]
substrings_v3 = [yearL[2:], yearH[2:]]
substrings_v4 = [yearL + yearH]
substrings_v5 = [yearL + yearH[2:]]
allSubstrings = [substrings_v1, substrings_v2, substrings_v3, substrings_v4, substrings_v5]

for link in soup.select("a[href*='.pdf']"):
    if conditions(allSubstrings, link):
        print(link.text)
# Out:
# Adur District Council's Statement of Accounts 2017-18 (1,926KB)
# Worthing Borough Council's Statement of Accounts 2017-18 (2,508KB)
# Adur District Council - Auditor Independent Report 2017-18 (4,735KB)
# Worthing Borough Council - Auditor Independent Report 2017-18 (4,736KB)

# %%
councilLinks_df.loc['adur', ['Link']][-1]
# Out:
# 'https://www.adur-worthing.gov.uk/about-the-councils/finance/statement-of-accounts/'

# %%
councilLinks_df.loc['adur']
# Out:
# Link    https://www.adur-worthing.gov.uk/about-the-cou...
# Name: adur, dtype: object

# %%
councilLinks_df
# Out:
#                                                            Link
# Councils
# adur          https://www.adur-worthing.gov.uk/about-the-cou...
# allerdale     https://www.allerdale.gov.uk/en/about-council/...
# amber valley  https://www.ambervalley.gov.uk/council/budgets...
# arun             https://www.arun.gov.uk/financial-information/
# ashfield      https://www.ashfield.gov.uk/your-council/publi...
# ...                                                         ...
# wychavon      https://www.wychavon.gov.uk/?option=com_filema...
# wycombe       https://www.wycombe.gov.uk/pages/About-the-cou...
# wyre          https://www.wyre.gov.uk/info/200339/council_bu...
# wyre forest   https://www.wyreforestdc.gov.uk/media/5999358/...
# york                https://www.york.gov.uk/StatementOfAccounts
#
# [383 rows x 1 columns]

# %%
findStatements(council = 'adur', yearL = '2017', yearH = '2018', pdfs = [])
# Out:
# ['https://www.adur-worthing.gov.uk/media/Media,149557,smxx.pdf',
#  'https://www.adur-worthing.gov.uk/media/Media,149558,smxx.pdf',
#  'https://www.adur-worthing.gov.uk/media/Media,154692,smxx.pdf',
#  'https://www.adur-worthing.gov.uk/media/Media,154693,smxx.pdf']

# %%
testURL = findStatements(councilLink = councilLinks[1], yearL = '2018', yearH = '2019', pdfs = [])

# %%
# tables = tabula.read_pdf(urls['Spelthorne'], pages = "all", multiple_tables = True)
#tables[-25][tables[-25].apply(lambda row: row.astype(str).str.contains('Current Assets' and 'Current Liabilities').any(), axis=1)]

def getTables(authority, url):
    tables = tabula.read_pdf(url, pages = 'all', multiple_tables = True)
    
    print("There are {} tables for {}".format(len(tables), authority))
    
    newTables = list()

    for i in range(len(tables)):

        terms1 = tables[i][tables[i].apply(lambda row: \
                                          row.astype(str).str.contains('Current Assets' \
                                                                       and 'Current Liabilities' \
                                                                       and 'Long term Liabilities'\
                                                                       and 'Long term Assets', \
                                                                       flags=re.IGNORECASE,
                                                                       regex = True
                                                                      ).any(), axis=1)]

        terms2 = tables[i][tables[i].apply(lambda row: \
                                          row.astype(str).str.contains('Current Assets' \
                                                                       and 'Current Liabilities' \
                                                                       and 'Long-term Liabilities'\
                                                                       and 'Long-term Assets', \
                                                                       flags=re.IGNORECASE,
                                                                       regex = True
                                                                      ).any(), axis=1)]
        
        if (terms1.shape[0] != 0) or (terms2.shape[0] != 0):
            newTables.append(tables[i])
    
    
    print("\n{} tables that might be of interest".format(len(newTables)))
    
    return newTables, pd.DataFrame(newTables[-1])

# %%
councilLinks_df.loc['sunderland', ['Link']][-1]
# Out:
# 'https://www.sunderland.gov.uk/article/14140/The-Council-s-accounts'

# %%
response = requests.get('https://www.sunderland.gov.uk/article/14186/2013-2014')

soup = BeautifulSoup(response.text, parse_only=SoupStrainer('a', href = True)) # parse_only=SoupStrainer('a', href = True)     

for link in soup.select("a[href*='pdf']")[1]:
    print(link['href'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-49ff7ed180c5> in <module>
#       4
#       5 for link in soup.select("a[href*='pdf']")[1]:
# ----> 6     print(link['href'])
#
# TypeError: string indices must be integers

# %%
# requests.get('https://www.burnley.gov.uk/about-council/finance-performance/statement-accounts-and-annual-reports')

# testBurnley = findStatements(councilLink = councilLinks_df.loc['burnley', ['Link']][-1], yearL = '2013', yearH = '2014', pdfs = [])

#requests.get(councilLinks_df.loc['sunderland', ['Link']][-1], verify = False)

# testEaling = findStatements(councilLink = councilLinks_df.loc['ealing', ['Link']][-1], yearL = '2013', yearH = '2014', pdfs = [])

testTMBC = findStatements(councilLink = councilLinks_df.loc['tmbc', ['Link']][-1], yearL = '2013', yearH = '2014', pdfs = [])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tmbc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-61bd71e4a607> in <module>
#       7 # testEaling = findStatements(councilLink = councilLinks_df.loc['ealing', ['Link']][-1], yearL = '2013', yearH = '2014', pdfs = [])
#       8
# ----> 9 testTMBC = findStatements(councilLink = councilLinks_df.loc['tmbc', ['Link']][-1], yearL = '2013', yearH = '2014', pdfs = [])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3489             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3490         else:
# -> 3491             loc = self.index.get_loc(key)
#    3492
#    3493             if isinstance(loc, np.ndarray):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'tmbc'

# %%
statementsDict13_14 = {el:[] for el in councilLinks_df.index.values.tolist()}
noPDFs = []
for el in statementsDict13_14:
    
    if el not in ['dartford', 'gravesham', 'tonbridge and malling']:
        statementsDict13_14[el] = findStatements(council = el, yearL = '2013', yearH = '2014', pdfs = [])
        print("Got council: {} ({} links found)".format(el, len(statementsDict13_14[el])))
    if len(statementsDict13_14[el]) == 0:
        noPDFs.append(el)
# Out:
# Got council: adur (47 links found)
# Got council: allerdale (1 links found)
# Got council: amber valley (0 links found)
# Got council: arun (36 links found)
# Got council: ashfield (3 links found)
# Got council: ashford (3 links found)
# Got council: avon fire (1 links found)
# Got council: aylesbury vale (2 links found)
# Got council: babergh (5 links found)
# Got council: barking and dagenham (3 links found)
# Got council: barnet (1 links found)
# Got council: barnsley (0 links found)
# Got council: barrow-in-furness (6 links found)
# Got council: basildon (3 links found)
# Got council: basingstoke and deane (0 links found)
# Got council: bassetlaw (3 links found)
# Got council: bath & north east somerset (0 links found)
# Got council: bedford (1 links found)
# Got council: bedfordshire fire (5 links found)
# Got council: berkshire fire authority (0 links found)
# Got council: bexley (1 links found)
# Got council: birmingham (0 links found)
# Got council: blaby (20 links found)
# Got council: blackburn with darwen (1 links found)
# Got council: blackpool (1 links found)
# Got council: bolsover (0 links found)
# Got council: bolton (0 links found)
# Got council: boston (0 links found)
# Got council: bournemouth (10 links found)
# Got council: bracknell forest (1 links found)
# Got council: bradford (0 links found)
# Got council: braintree (0 links found)
# Got council: breckland (1 links found)
# Got council: brent (0 links found)
# Got council: brentwood (15 links found)
# Got council: brighton & hove (4 links found)
# Got council: bristol (1 links found)
# Got council: broadland (4 links found)
# Got council: bromley (0 links found)
# Got council: bromsgrove (2 links found)
# Got council: broxbourne (2 links found)
# Got council: broxtowe (4 links found)
# Got council: buckinghamshire (2 links found)
# Got council: buckinghamshire fire (0 links found)
# Got council: burnley (1 links found)
# Got council: bury (0 links found)
# Got council: calderdale (0 links found)
# Got council: cambridge (1 links found)
#   'https://www.basildon.gov.uk/media/1496/Summary-of-Accounts-2007-08/pdf/basildon_district_council_-_summary_of_accounts_2007-2008.pdf?m=635116432136270000'],
#  'basingstoke and deane': [],
#  'bassetlaw': ['https://data.bassetlaw.gov.uk/media/8095/statement-of-accounts-19-20.pdf',
#   'https://data.bassetlaw.gov.uk/media/8098/audit-closure-letter-2019-20.pdf',
#   'https://data.bassetlaw.gov.uk/media/8097/2019-20-bassetlaw-dc-aal.pdf'],
#  'bath & north east somerset': [],
#  'bedford': ['https://bbcdevwebfiles.blob.core.windows.net/webfiles/Files/Audited_Statement_of_Accounts_2013-2014.pdf'],
#  'bedfordshire fire': ['https://www.bedsfire.gov.uk/About/Finance-and-budget/Completion-of-Audit-Advert-Dec-2020-002.pdf',
#   'https://www.bedsfire.gov.uk/About/Finance-and-budget/Final-audited-Statement-of-Accounts-2019-20-with-signatures-002.pdf',
#   'https://www.bedsfire.gov.uk/About/Finance-and-budget/Monthly-Financial-Reports/Audited-Statement-of-Accounts-2018-19-20th-November-2019.pdf',
#   'https://www.bedsfire.gov.uk/About/Finance-and-budget/Statement-of-Accounts-2017-18-FINAL.pdf',
#   'https://www.bedsfire.gov.uk/About/Finance-and-budget/Accounts-2016-2017-FINAL-signed-version.pdf'],
#  'berkshire fire authority': [],
#  'bexley': ['https://www.bexley.gov.uk/sites/default/files/2020-07/Statement-of-Accounts-DRAFT-2019-2020.pdf'],
#  'birmingham': [],
#  'blaby': ['https://www.blaby.gov.uk/media/3924/public-inspection-notice-2019-20.pdf',
#   'https://www.blaby.gov.uk/media/3925/appendix-a-draft-annual-governance-statement-2019-20.pdf',
#   'https://www.blaby.gov.uk/media/3926/draft-financial-statement-2019-20-unaudited-version.pdf',
#   'https://www.blaby.gov.uk/media/4142/notice-of-appointment-of-auditors.pdf',
#   'https://www.blaby.gov.uk/media/2858/asset-register-2017.pdf',
#   'https://www.blaby.gov.uk/media/2094/notice-of-completion-of-the-audit-of-accounts-july-2018.pdf',
#   'https://www.blaby.gov.uk/media/4115/statement-of-accounts-2018.pdf',
#   'https://www.blaby.gov.uk/media/2096/annual-governance-statement-2017-18.pdf',
#   'https://www.blaby.gov.uk/media/2102/financial-statement-2016-17.pdf',
#   'https://www.blaby.gov.uk/media/2104/notice-of-completion-of-audit-of-accounts-2016-17.pdf',
#   'https://www.blaby.gov.uk/media/2100/annual-governance-statement-2016-17.pdf',
#   'https://www.blaby.gov.uk/media/2101/audit-opinion-2015-16.pdf',
#   'https://www.blaby.gov.uk/media/2103/notice-of-completion-of-audit-of-accounts-2015-16.pdf',
#   'https://www.blaby.gov.uk/media/2106/annual-governance-statement-2015-16.pdf',
#   'https://www.blaby.gov.uk/media/2105/statement-of-accounts-2015-16.pdf',
#   'https://www.blaby.gov.uk/media/3460/statement-of-accounts-2018-2019.pdf',
#   'https://www.blaby.gov.uk/media/3457/notice-of-completion-july-2019.pdf',
#   'https://www.blaby.gov.uk/media/3933/annual-governance-statement-2018-19-appendix-a.pdf',
#   'https://www.cheshireeast.gov.uk/pdf/council-and-democracy/statement-of-accounts/annual_governance_statement_13-14_final.pdf',
#   'https://www.cheshireeast.gov.uk/pdf/council-and-democracy/statement-of-accounts/public_notice_conclusion_of_audit_2013-14.pdf'],
#  'cheshire fire': ['https://www.cheshirefire.gov.uk/Assets/1/Statement-of-Accounts-2013-14.pdf'],
#  'cheshire west & chester': ['http://inside.cheshirewestandchester.gov.uk/GetFile?fileUrl=/iCWAC%20Documents/StatementofAccounts1314.pdf&extension=pdf',
#   'http://inside.cheshirewestandchester.gov.uk/GetFile?fileUrl=/iCWAC%20Documents/SummaryStatementofAccounts1314.pdf&extension=pdf'],
#  'chesterfield': ['https://www.chesterfield.gov.uk/media/145579/statement-of-accounts-13-14.pdf',
#   'https://www.chesterfield.gov.uk/media/145767/cbc-annual-audit-letter-2013-14.pdf',
#   'https://www.chesterfield.gov.uk/media/145576/statement-of-accounts-12-13.pdf'],
#  'chichester': ['https://www.chichester.gov.uk/media/22699/Statement-of-Accounts-2013-14/pdf/CDC_Audited_Statement_of_Accounts_2013-14.pdf',
#   'https://www.chichester.gov.uk/media/22698/Auditors-Report-2013-14/pdf/Audit_Results_Report.pdf',
#   'https://www.chichester.gov.uk/media/22877/Audit-Letter-2013-14/pdf/CDC_Annual_Audit_Letter_2013-14_Final.pdf',
#   'https://www.chichester.gov.uk/media/22720/Annual-Governance-Statement-2013-14/pdf/Annual_Governance_Statement_2013-14_.pdf'],
#  'chiltern': ['https://www.chiltern.gov.uk/media/9842/2013-14-Statement-of-Accounts/pdf/CDC_STATEMENT_OF_ACCOUNTS_1314.pdf?m=637211763160600000'],
#  'chorley': ['https://chorley.gov.uk/media/311/Statement-of-Accounts-2014-2015/pdf/statement_of_accounts_14-15.pdf?m=637352485631370000',
#   'https://chorley.gov.uk/media/312/Statement-of-Accounts-2013-2014/pdf/statement_of_accounts_13-14.pdf?m=637352485953730000'],
#  'christchurch': ['https://www.christchurch.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/christchurch-accounts-docs/notice-of-audit-completion-201819.pdf',
#   'https://www.christchurch.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/christchurch-accounts-docs/statement-of-accounts-2018-19.pdf',
#   'https://www.christchurch.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/christchurch-accounts-docs/statement-of-accounts-christchurch-borough-council-2017.2018.pdf',
#   'https://www.christchurch.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/christchurch-accounts-docs/statement-of-accounts-2016-17.pdf',
#   'https://www.christchurch.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/christchurch-accounts-docs/statement-of-accounts-2015-16.pdf',
#   'https://www.christchurch.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/christchurch-accounts-docs/statement-of-accounts-2014-15.pdf'],
#  'city of london': [],
#  'cleveland fire': [],
#  'colchester': ['https://cbccrmdata.blob.core.windows.net/noteattachment/CBC%20-%20How%20The%20Council%20Works%20-%20Statement%20of%20Accounts%20Colchester%20Borough%20Council%20-%20Statement%20of%20Accounts%202013-14.pdf',
#   'https://cbccrmdata.blob.core.windows.net/noteattachment/CBC%20-%20How%20The%20Council%20Works%20-%20Statement%20of%20Accounts%20Colchester%20Borough%20Council%20-%20Summary%20Statement%20of%20Accounts%202013-14.pdf'],
#  'copeland': ['https://www.copeland.gov.uk/sites/default/files/attachments/soa_18_19_final.pdf'],
#  'corby': [],
#  'cornwall': ['https://www.cornwall.gov.uk/media/8886751/cornwall-council-statement-of-accounts-2013-14-post-audit-pre-wga-with-signatures.pdf',
#   'https://www.cornwall.gov.uk/media/8805088/tbtf-statement-of-accounts-2013_14.pdf',
#   'https://www.cornwall.gov.uk/media/9921745/2013-14-annual-audit-letter-final-cc.pdf',
#   'https://www.cornwall.gov.uk/media/9921746/2013-14-tbtf-jc-annual-audit-letter.pdf',
#   'https://www.cornwall.gov.uk/media/7620368/assets-under-construction-2013-14.pdf',
#   'https://www.cornwall.gov.uk/media/7
#  'devon and somerset fire': ['https://www.dsfire.gov.uk/AboutUs/WhatWeSpend/StatementOfAccounts/documents/DSFRAStatementofAccounts2013-14.pdf',
#   'https://www.dsfire.gov.uk/AboutUs/WhatWeSpend/StatementOfAccounts/documents/AnnualStatementofAssurance201314.pdf'],
#  'doncaster': ['https://dmbcwebstolive01.blob.core.windows.net/media/Default/Council%20and%20Democracy/Statement%20of%20Accounts%202019-20.pdf',
#   'https://dmbcwebstolive01.blob.core.windows.net/media/Default/Council%20and%20Democracy/2019-20%20Annual%20Governance%20Statement.pdf',
#   'https://dmbcwebstolive01.blob.core.windows.net/media/Default/Council%20and%20Democracy/Notice%20of%20Conclusion%20of%20the%202019-20%20Audit.pdf',
#   'https://dmbcwebstolive01.blob.core.windows.net:443/media/Default/Council%20and%20Democracy/Documents/Notification%20of%20Appointment%20of%20External%20Auditors.pdf'],
#  'dorset': ['https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/dorset-council-accounts-docs/accounts-2019-20.pdf',
#   'https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/dorset-council-accounts-docs/notice-of-accounts-for-2019-20-dorset-councilv2.pdf',
#   'https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/shadow-dorset-council/shadow-dorset-council-agar-2018-19-declaration-of-no-accounts.pdf'],
#  'dorset and wiltshire fire': [],
#  'dover': ['https://www.dover.gov.uk/Corporate-Information/Financial-Information/PDF/StatementofAccounts2013-14.pdf',
#   'https://www.dover.gov.uk/Corporate-Information/Financial-Information/PDF/Budget2013-14andMTFP2013-14to2015-16.pdf',
#   'https://www.dover.gov.uk/Corporate-Information/Financial-Information/PDF/Final-Gov-Ass-statement-2013-14.pdf',
#   'https://www.dover.gov.uk/Corporate-Information/Financial-Information/PDF/Budgetfor2012-13andMediumTermFinancialPlan2012-13to2014-15.pdf',
#   'https://www.dover.gov.uk/Corporate-Information/Financial-Information/PDF/Budgetfor2011-12andMediumTermFinancialPlan2011-12to2013-14.pdf'],
#  'dudley': ['https://www.dudley.gov.uk/media/16942/statement_of_accounts_2019-20.pdf',
#   'https://www.dudley.gov.uk/media/17262/conclusion_of_audit_201920.pdf',
#   'https://www.dudley.gov.uk/media/17263/dmbc_final_audit_certificate_19_20_signed.pdf'],
#  'durham': ['https://www.durham.gov.uk/media/34832/Audit-Certificate-in-respect-of-Durham-County-Council-for-the-2019-20-financial-year/pdf/AuditCertificateDurhamCountyCouncil2019-20.pdf?m=637481426161330000',
#   'https://www.durham.gov.uk/media/5230/Statement-of-accounts-2013-2014/pdf/StatementofAccounts2013-14Audited.pdf?m=635712733051830000',
#   'https://www.durham.gov.uk/media/1405/Statement-of-accounts-2012-2013/pdf/AccStatement2012-2013.pdf?m=636058327530370000'],
#  'durham fire': [],
#  'ealing': ['https://www.ealing.gov.uk/downloads/download/3249/statement_of_accounts_2013-14'],
#  'east cambridgeshire': ['https://www.eastcambs.gov.uk/sites/default/files/ANNUAL%20GOVERNANCE%20STATEMENT%202013-14.pdf',
#   'https://www.eastcambs.gov.uk/sites/default/files/1314%20FOREWORD%20TO%20SOA%20FOR%20WEB.pdf',
#   'https://www.eastcambs.gov.uk/sites/default/files/1314%20SOA%20FOR%20WEB.pdf',
#   'https://www.eastcambs.gov.uk/sites/default/files/13-14%20ECDC%20audit%20opinion%20for%20ECDC%20website.pdf',
#   'https://www.eastcambs.gov.uk/sites/default/files/summarised%20accounts%2013-14_0.pdf',
#   'https://www.eastcambs.gov.uk/sites/default/files/Approvedbudget1314.pdf'],
#  'east devon': ['https://eastdevon.gov.uk/media/3720871/soa-2019-20-draft-v1.pdf',
#   'https://eastdevon.gov.uk/media/3720925/annual-goverance-statement-2019-20.pdf',
#   'https://eastdevon.gov.uk/media/3720872/notice-of-audit-inspection-2019-20.pdf',
#   'https://eastdevon.gov.uk/media/3720954/financial-strategy-2019-2029.pdf',
#   'https://eastdevon.gov.uk/media/3720874/cab-mtfp-eddc-mtfp-2019-2029-apendix-a-converted.pdf',
#   'https://eastdevon.gov.uk/media/3720873/cab-mtfp-eddc-mtfp-2019-2029-appendix-a-i-converted.pdf',
#   'https://eastdevon.gov.uk/media/2935824/Transformation-Strategy-Refresh-2018-KJ-v2.pdf',
#   'https://eastdevon.gov.uk/media/2902792/Estimates-Book-2019-20-in-PDF.pdf',
#   'https://eastdevon.gov.uk/media/3720957/treasury-management-strategy-statement-2019-20.pdf',
#   'https://eastdevon.gov.uk/media/2902795/Capital-Strategy-2019.pdf'],
#  'east dorset': ['https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/east-dorset-accounts-docs/eddc-annual-audit-letter-2018-19.pdf',
#   'https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/east-dorset-accounts-docs/eddc-public-notice-of-completion-of-audit-2018-19.pdf',
#   'https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/east-dorset-accounts-docs/1.1.2-draft-eddc-2018-19-statement-of-accounts-audit-adj-drc-mccloud.pdf',
#   'https://www.dorsetcouncil.gov.uk/your-council/about-your-council/budgets-and-spending/annual-accounts/east-dorset-accounts-docs/statement-of-accounts-east-dorset-district-council-2017.2018.pdf'],
#  'east hampshire': ['https://www.easthants.gov.uk/final-accounts-2013-14-pdf-2-mb'],
#  'east hertfordshire': ['https://www.eastherts.gov.uk/sites/default/files/documents/Statement_of_Accounts_2013-14.pdf'],
#  'east lindsey': ['https://www.e-lindsey.gov.uk/media/5930/ELDC-Published-Financial-Statements-2014-15/pdf/ELDC_Published_Financial_Statements_2014-15.pdf?m=636410067133970000',
#   'https://www.e-lindsey.gov.uk/media/5931/ELDC-Published-Financial-Statements-2013-14/pdf/ELDC_Published_Financial_Statements_2013-14.pdf?m=636410067672270000'],
#  'east northamptonshire': ['https://www.east-northamptonshire.gov.uk/downloads/file/7005/statement_of_accounts_2013-14'],
#  'east riding of yorkshire': [],
#  'east staffordshire': ['http://www.eaststaffsbc.gov.uk/sites/default/files/docs/finance/StatementofAccounts2013-14.pdf'],
#  'east sussex': ['https://www.eastsussex.gov.uk/media/2765/statement-of-accounts-2013-14.pdf'],
#  'east sussex fire': [],
#  'eastbourne': ['https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/290241.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/284864.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/291005.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/272166.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260157.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260177.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260176.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260175.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260156.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260155.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260170.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260169.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/291931.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/290240.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/284863.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/291004.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/280954.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/273132.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/262648.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260253.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260252.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260250.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260249.pdf',
#   'https://www.lewes-eastbourne.gov.uk/_resources/assets/inline/full/0/260248.pdf'],
#  'eastleigh': ['https://www.eastleigh.gov.uk/media/2182/statement-of-accounts-2013-2014.pdf'],
#  'eden': ['https://www.eden.gov.uk/media/5826/eden-draft-statement-of-accounts-2019-2020.pdf'],
#  'elmbridge': ['https://www.elmbridge.gov.uk/_resources/assets/attachment/full/0/7617.pdf',
#   'https://www.elmbridge.gov.uk/_resources/assets/attachment/full/0/7618.pdf',
#   'https://www.elmbridge.gov.uk/_resources/assets/attachment/full/0/6950.pdf',
#   'https://www.elmbridge.gov.uk/_resources/assets/attachment/full/0/7142.pdf',
#   'https://www.elmbridge.gov.uk/_resources/assets/attachment/full/0/5717.pdf',
#   'https://www.elmbridge.gov.uk/_resources/assets/attachment/full/0/7537.pdf'],
#  'enfield': ['https://new.enfield.gov.uk/services/your-council/statement-of-accounts/your-council-information-final-audited-statement-of-accounts-2013-14.pdf'],
#  'epping forest': ['http://www.adobe.com/go/acrobat11_accessibility_checker_en#ImageOnlyPDF'],
#  'epsom and ewell': ['https://www.epsom-ewell.gov.uk/sites/default/files/documents/council/about-council/Audited statement of accounts 2013-2014.pdf'],
#  'erewash': ['https://erewash.gov.uk/images/The_Council/Council_budget_and_spending/Annual_Statement_of_Accounts_2019_20_FINAL_PREAUDIT.pdf'],
#  'essex': ['https://assets.ctfassets.net/knkzaf64jx5x/YQiOAPKkh54ux7HjA7Z57/b2a4ae9496fc028dc92f5f71ad7d6c00/Statement_of_accounts_2013_2014.pdf',
#   'https://assets.ctfassets.net/knkzaf64jx5x/14BpWInWmEBAaOGViAipG7/306b13c94dd97a6ae75bc191302d7730/2021-22_Fees_and_Charges_Schedule.pdf'],
#  'essex fire auhtority': ['https://www.essex-fire.gov.uk/_img/pics/pdf_1502110120.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1533043268.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1550829308.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1550829341.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1576232808.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1603883812.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1603884204.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1603884926.pdf',
#   'https://www.essex-fire.gov.uk/_img/pics/pdf_1608047798.pdf'],
#  'exeter': ['https://exeter.gov.uk/media/1337/statement_of_accounts_2013_-_2014.pdf'],
#  'fareham': [],
#  'fenland': [],
#  'forest heath': ['https://www.westsuffolk.gov.uk/Council/Finance_and_Statistics/upload/FHDCStatementofAccounts2013-14FINAL.pdf',
#   'https://www.westsuffolk.gov.uk/Council/Finance_and_Statistics/upload/2013-14-SEBC-Statement-of-Accounts-6.pdf'],
#  'forest of dean': [],
#  'fylde': ['https://new.fylde.gov.uk/wp-content/uploads/2020/12/18-19-Post-audit-SoA-as-at-31st-March-2019-Final.pdf'],
#  'gateshead': ['https://www.gateshead.gov.uk/media/2981/Statement-of-Accounts-13-14/pdf/Statement-of-Accounts-13-14.pdf?m=636410014371500000',
#   'https://www.gateshead.gov.uk/media/2996/Statement-of-Accounts-2012-13/pdf/Statement-of-Accounts-2012-13.pdf?m=636410014416700000'],
#  'gedling': ['https://www.gedling.gov.uk/media/gedlingboroughcouncil/documents/council/aboutus/accounts/AUDITED Statement of Accounts 1920 (POST AUDIT) For Publication.pdf',
#   'https://www.gedling.gov.uk/media/gedlingboroughcouncil/documents/council/aboutus/accounts/External Audit Completion Report -  17.11.2020 v2 LATEST.pdf',
#   'https://www.gedling.gov.uk/media/gedlingboroughcouncil/documents/council/aboutus/accounts/External Audit Follow up letter FINAL.pdf'],
#  'gloucester': ['https://www.gloucestershire.gov.uk/media/2778/final_consolidated_soa_2013-14-60815.pdf',
#   'https://www.gloucestershire.gov.uk/media/3021/local_code_of_corporate_governance_2013-14_final-67410.pdf'],
#  'gloucestershire': ['https://www.gloucestershire.gov.uk/media/2778/final_consolidated_soa_2013-14-60815.pdf',
# ...
#   'https://www.warrington.gov.uk/sites/default/files/2019-08/2013-14_value_for_money_report.pdf',
#   'https://www.warrington.gov.uk/sites/default/files/2019-08/2013-14_statement_of_accounts.pdf'],
#  'warwick': ['https://www.warwickdc.gov.uk/downloads/download/546/statement_of_accounts_2013-14'],
#  'warwickshire': ['http://apps.warwickshire.gov.uk/api/documents/WCCC-943-207'],
#  'watford': [],
#  'waveney': ['https://www.eastsuffolk.gov.uk/assets/Your-Council/Financial-Information/Statement-of-Accounts
#  'wyre': ['http://www.wyre.gov.uk/download/downloads/id/5795/statutory_notice_of_public_inspection_of_accounts_-_year_ended_31_march_2019.pdf',
#   'http://www.wyre.gov.uk/download/downloads/id/5842/statement_of_accounts_-_year_ended_31_march_2019.pdf',
#   'http://www.wyre.gov.uk/download/downloads/id/5093/statutory_notice_of_public_inspection_of_accounts_-_year_ended_31_march_2018.pdf',
#   'http://www.wyre.gov.uk/download/downloads/id/5800/statement_of_accounts_-_year_ended_31032018.pdf',
#   'https://wyre.moderngov.co.uk/documents/s2672/Questions%20and%20answers%202017-18%20-%20Audit%20Cttee%20Version%20FINAL.pdf',
#   'https://wyre.moderngov.co.uk/documents/s2419/Wyre%20BC%20ISA%20260%20Report%20201718.pdf',
#   'http://www.wyre.gov.uk/download/downloads/id/5372/notice_of_conclusion_of_the_audit_of_accounts_2017-18.pdf',
#   'https://wyre.moderngov.co.uk/documents/g1417/Public%20reports%20pack%2001st-Dec-2020%20Constitution.pdf?T=10 '],
#  'wyre forest': [],
#  'york': []}

# %%
test_all_tables, test_last_table_df  = getTables('Ashfield', testURL[0])
# Out:
# Got stderr: Mar 14, 2021 1:13:42 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:13:43 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:13:46 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:14:00 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:14:07 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:14:08 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:14:08 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# Mar 14, 2021 1:14:08 AM org.apache.fontbox.ttf.CmapSubtable processSubtype14
# WARNING: Format 14 cmap table is not supported and will be ignored
# There are 190 tables for Ashfield
#
# 1 tables that might be of interest

# %%
test_last_table_df
# Out:
#                                     Unnamed: 0 Unnamed: 1 At 31/03/19  \
# 0                                          NaN        NaN         NaN
# 1                                          NaN        NaN         NaN
# 2                                          NaN       Note       £’000
# 3                  Property, Plant & Equipment         G5      63,985
# 4                              Heritage Assets         G6       2,482
# 5                          Investment Property         21      24,841
# 6                            Intangible Assets          -          53
# 7                        Long-term Investments         24       1,673
# 8   Investments in Associates & Joint Ventures        NaN           0
# 9                            Long-term Debtors          -         187
# 10                            Long-term Assets        NaN      93,221
# 11                                         NaN        NaN         NaN
# 12                      Short-term Investments         24           0
# 13                                   Inventory          -          76
# 14                          Short-term Debtors         25       5,806
# 15                                 Prepayments          -       1,194
# 16                   Cash and Cash Equivalents         27       6,373
# 17                        Assets held for sale          -           0
# 18                              Current Assets        NaN      13,449
# 19                                         NaN        NaN         NaN
# 20                              Bank Overdraft         27     (1,959)
# 21                        Short-term Borrowing          -       (593)
# 22                        Short-term Creditors         29     (7,486)
# 23              Contract and Other liabilities         30     (2,222)
# 24                                  Provisions         31     (1,255)
# 25                         Current Liabilities        NaN    (13,515)
# 26                                         NaN        NaN         NaN
# 27   Long-term Creditors & Receipts in Advance          -       (258)
# 28                                  Provisions         31       (287)
# 29                         Long-term Borrowing         28    (14,747)
# 30                            Deferred Credits          -        (70)
# 31              Defined Benefit Pension Scheme         32    (33,474)
# 32                       Long-term Liabilities        NaN    (48,836)
# 33                                  Net Assets        NaN      44,319
# 34                                         NaN        NaN         NaN
# 35                             Usable Reserves         G4       8,852
# 36                           Unusable Reserves         G4      35,467
# 37                              Total Reserves        NaN      44,319
#
#    At 31/03/18
# 0          NaN
# 1          NaN
# 2        £'000
# 3       57,291
# 4        2,476
# 5       23,457
# 6            9
# 7        1,646
# 8            0
# 9           35
# 10      84,914
# 11         NaN
# 12           0
# 13          84
# 14       4,726
# 15       1,093
# 16       7,139
# 17           0
# 18      13,042
# 19         NaN
# 20     (1,805)
# 21       (581)
# 22     (3,822)
# 23     (1,209)
# 24     (1,016)
# 25     (8,433)
# 26         NaN
# 27       (290)
# 28       (311)
# 29    (15,067)
# 30        (70)
# 31    (28,802)
# 32    (44,540)
# 33      44,983
# 34         NaN
# 35      10,189
# 36      34,794
# 37      44,983

# %%
test_last_table_df
# Out:
#                                     Unnamed: 0 Unnamed: 1 At 31/03/19  \
# 0                                          NaN        NaN         NaN
# 1                                          NaN        NaN         NaN
# 2                                          NaN       Note       £’000
# 3                  Property, Plant & Equipment         G5      63,985
# 4                              Heritage Assets         G6       2,482
# 5                          Investment Property         21      24,841
# 6                            Intangible Assets          -          53
# 7                        Long-term Investments         24       1,673
# 8   Investments in Associates & Joint Ventures        NaN           0
# 9                            Long-term Debtors          -         187
# 10                            Long-term Assets        NaN      93,221
# 11                                         NaN        NaN         NaN
# 12                      Short-term Investments         24           0
# 13                                   Inventory          -          76
# 14                          Short-term Debtors         25       5,806
# 15                                 Prepayments          -       1,194
# 16                   Cash and Cash Equivalents         27       6,373
# 17                        Assets held for sale          -           0
# 18                              Current Assets        NaN      13,449
# 19                                         NaN        NaN         NaN
# 20                              Bank Overdraft         27     (1,959)
# 21                        Short-term Borrowing          -       (593)
# 22                        Short-term Creditors         29     (7,486)
# 23              Contract and Other liabilities         30     (2,222)
# 24                                  Provisions         31     (1,255)
# 25                         Current Liabilities        NaN    (13,515)
# 26                                         NaN        NaN         NaN
# 27   Long-term Creditors & Receipts in Advance          -       (258)
# 28                                  Provisions         31       (287)
# 29                         Long-term Borrowing         28    (14,747)
# 30                            Deferred Credits          -        (70)
# 31              Defined Benefit Pension Scheme         32    (33,474)
# 32                       Long-term Liabilities        NaN    (48,836)
# 33                                  Net Assets        NaN      44,319
# 34                                         NaN        NaN         NaN
# 35                             Usable Reserves         G4       8,852
# 36                           Unusable Reserves         G4      35,467
# 37                              Total Reserves        NaN      44,319
#
#    At 31/03/18
# 0          NaN
# 1          NaN
# 2        £'000
# 3       57,291
# 4        2,476
# 5       23,457
# 6            9
# 7        1,646
# 8            0
# 9           35
# 10      84,914
# 11         NaN
# 12           0
# 13          84
# 14       4,726
# 15       1,093
# 16       7,139
# 17           0
# 18      13,042
# 19         NaN
# 20     (1,805)
# 21       (581)
# 22     (3,822)
# 23     (1,209)
# 24     (1,016)
# 25     (8,433)
# 26         NaN
# 27       (290)
# 28       (311)
# 29    (15,067)
# 30        (70)
# 31    (28,802)
# 32    (44,540)
# 33      44,983
# 34         NaN
# 35      10,189
# 36      34,794
# 37      44,983

# %%
# urls = dict({
#     'Spelthorne': 'https://www.spelthorne.gov.uk/media/23068/Draft-Statement-of-Accounts-2019-20/pdf/SoA_2019-20_100920_update1.pdf?m=637353494717970000',
#     'Nottingham': 'https://www.nottinghaminsight.org.uk/d/aaCFHALE'})
